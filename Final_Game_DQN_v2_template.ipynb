# %%
import pygame
import os
import sys

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.backends.cudnn as cudnn
cudnn.benchmark = True

import numpy as np
from PIL import Image
import random
import matplotlib.pyplot as plt
from matplotlib import animation
from collections import deque

# %%
print(torch.cuda.is_available())  # 應該為 True
print(torch.version.cuda)         # 應該列出 CUDA 版本
print(torch.backends.cudnn.version())  # cuDNN 版本
# Out:
# True
# 12.1
# 90100

# %%
script_dir = os.path.join(os.getcwd(), 'space_ship_game_RL')
if script_dir not in sys.path:
    sys.path.append(script_dir)

from setting import *
from game import Game

# %%
class SpaceShipEnv():
    def __init__(self):
        pygame.init()
        pygame.font.init()

        # 延後畫面初始化，等 render() 時才設置
        self.screen = None
        self.clock = pygame.time.Clock()
        self.fps = FPS

        self.game = Game()

        self.action_space = [0, 1, 2, 3]
        self.observation = self.game.state
        self.prev_score = 0
        self.prev_health = self.game.player.sprite.health

    def step(self, action):
        self.game.update(action)

        if self.screen is None:
            self.game.draw()
        else:
            self.game.draw(self.screen)
            self.clock.tick(self.fps)

        # define the state by your game logic
        state = self.game.state

        # define the reward by your game logic
        reward = 0.0

        # 擊中石頭
        if self.game.is_hit_rock:
            hit_inc = self.game.score - self.prev_score      # 新增分數差
            # rock.radius 已映射進分數增量，可直接用
            reward +=  1.5*hit_inc                     # 相當於 k1≈0.2*2 = 0.4

        # 撿到護盾 / 武器
        if self.game.is_power_shield:
            reward += 5
        if self.game.is_power_gun:
            reward += 3

        # 撞到石頭（血量已在 game.collide_player_rock 調整）
        if self.game.is_collided:
            damage = self.game.is_collided_radius   # 你可在 collide_player_rock 回傳 radius
            reward -= 15 * (damage / 10)

        # 存活獎勵
        reward += 0.2

        # 死亡懲罰（再降低）
        if not self.game.running:
            reward -= 200
        # 更新上一步的狀態
        self.prev_score = self.game.score
        self.prev_health = self.game.player.sprite.health
        # ------------------------------------
    
        done = not self.game.running or self.game.score >= 10000

        info = {
            "score": self.game.score,
            "health": self.game.player.sprite.health
        }

        return state, reward, done, info

    def reset(self):
        self.game = Game()
        self.prev_score = 0
        return self.game.state

    def render(self):
        if self.screen is None:
            self.screen = pygame.display.set_mode((WIDTH, HEIGHT))
            pygame.display.set_caption("SpaceShip RL Environment")

    def close(self):
        pygame.quit()

# %%
# Hyperparameters
num_episodes = 4000
batch_size = 256
gamma = 0.99
lr = 1e-4
epsilon_start = 1.0
epsilon_end = 0.01
epsilon_decay = 0.999
memory_capacity = 100000  # 100000
target_update_freq = 2000   # 1000

# %%
epsilon_list=[]
epsilon=epsilon_start
for i in range(num_episodes):
    epsilon = max(epsilon_end, epsilon * epsilon_decay)
    epsilon_list.append(epsilon)
plt.plot(epsilon_list)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# CNN-based DQN Model
class DQN(nn.Module):
    def __init__(self, in_channels, num_actions):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, 32, kernel_size=8, stride=4),  # (C,84,84)→(32,20,20)
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),           # →(64,9,9)
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),           # →(64,7,7)
            nn.ReLU(),
        )
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 7 * 7, 512),
            nn.ReLU(),
            nn.Linear(512, num_actions)
        )


    def forward(self, x):
        x = self.conv(x / 255.0) 
        return self.fc(x)

# %%
# Replay buffer
# 用於儲存代理人經驗（狀態、動作、獎勵等）的緩衝區，支援隨機抽樣以打破時間相關性，有助於穩定訓練。

class ReplayMemory:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
        # Use deque with a fixed capacity to automatically discard the oldest experience when full.
        # 使用 deque 並設定最大長度，當容量滿時會自動移除最舊的資料。

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))
        # Store a single transition (experience) in the buffer.
        # 儲存一筆經驗（狀態轉移）進緩衝區。

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        # Randomly sample a batch of transitions to break correlation between consecutive samples.
        # 隨機抽取一批經驗，打破樣本間的時間關聯性，提高訓練穩定性。

        # Unpack each element into separate tensors for network input
        # 將 batch 拆解成分別的 tensor 以供神經網路訓練
        states, actions, rewards, next_states, dones = zip(*batch)
        
        # Convert the sampled data into tensors and move them to the specified device (CPU or GPU)
        # 將抽樣資料轉成 tensor 並移至指定設備（CPU/GPU）

        # states = torch.tensor(np.stack(states), dtype=torch.float32, device=device)
        # actions = torch.tensor(actions, dtype=torch.int64, device=device)
        # rewards = torch.tensor(rewards, dtype=torch.float32, device=device)
        # next_states = torch.tensor(np.stack(next_states), dtype=torch.float32, device=device)
        # dones = torch.tensor(dones, dtype=torch.float32, device=device)
        # return states, actions, rewards, next_states, dones
        # 檢查 state shape
        
        # 先在 CPU 上創建 Tensor，然後 pin memory 
        states = torch.stack(states).pin_memory()
        actions = torch.tensor(actions, dtype=torch.int64).unsqueeze(1).pin_memory()
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(1).pin_memory()
        next_states = torch.stack(next_states).pin_memory()
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(1).pin_memory()
        
        return states, actions, rewards, next_states, dones
    
        # return (
        #     torch.stack(states),
        #     torch.tensor(actions, dtype=torch.int64, device=device).unsqueeze(1),  # Add dimension for actions
        #     torch.tensor(rewards, dtype=torch.float32, device=device).unsqueeze(1),  # Add dimension for rewards    
        #     torch.stack(next_states),
        #     torch.tensor(dones, dtype=torch.float32, device=device).unsqueeze(1)  # Add dimension for dones
        # )

    def __len__(self):
        return len(self.buffer)
        # Return the current size of the buffer.
        # 回傳緩衝區目前儲存的資料數量。

# %%
# Preprocess frames (grayscale and resize to 84x84)
# 預處理影格：轉為灰階並縮放為 84x84

import cv2
def preprocess_state(state, stacked_state=None, is_new=False):
    gray = cv2.cvtColor(state, cv2.COLOR_RGB2GRAY)
    gray = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA)
    gray = torch.tensor(gray, dtype=torch.uint8).unsqueeze(0)        # (1,84,84)
    if is_new or stacked_state is None:
        stacked_state = gray.repeat(4, 1, 1)                         # (4,84,84)
    else:
        stacked_state = torch.cat((gray, stacked_state[:-1]), dim=0)
    return stacked_state.float().unsqueeze(0), stacked_state         # (1,4,84,84)


def preprocess_frame(frame):
    # frame 是 numpy array (H, W, 3)，先轉為 PIL Image
    # Input is a color image (RGB), convert to PIL format for easier processing.
    # 輸入是彩色圖像（RGB），轉成 PIL Image 以方便處理。
    image = Image.fromarray(frame)

    # 轉灰階
    # Convert the image to grayscale to reduce input complexity.
    # 將影像轉為灰階，降低輸入維度與計算量。
    image = image.convert('L')

    # resize 成 84x84
    # Resize the image to a standard 84x84 shape, as per DQN convention.
    # 依照 DQN 的慣例將影像統一縮放至 84x84。
    image = image.resize((84, 84), Image.Resampling.BILINEAR)  # or NEAREST, or LANCZOS

    # 轉回 numpy 並正規化
    # Convert back to NumPy and normalize pixel values to [0, 1].
    # 轉回 NumPy 格式並將像素值標準化到 [0, 1]。
    frame = np.asarray(image, dtype=np.float32) / 255.0

    return frame


def stack_frames(stacked_frames, state, is_new_episode):
    # 預處理目前影格
    frame = preprocess_frame(state)

    if is_new_episode or stacked_frames is None:
        # If it's a new episode or no previous frames, initialize with 4 identical frames
        # 若是新的一集或是尚未初始化，則用目前影格複製 4 次形成初始堆疊
        stacked_frames = deque([frame]*4, maxlen=4)
    else:
        # 否則把新影格加入到堆疊中，自動捨棄最舊的
        stacked_frames.append(frame)

    # Stack the 4 frames along the first dimension: shape becomes (4, 84, 84)
    # 沿著第一維（channel）堆疊成 4 通道輸入：形狀變成 (4, 84, 84)
    stacked_state = np.stack(stacked_frames, axis=0)

    return stacked_state, stacked_frames

# %%
# 初始化 Breakout 環境 / Initialize the Breakout environment
import torch.amp

env = SpaceShipEnv()
num_actions = len(env.action_space)
state_dim = 4
# 建立策略網路與目標網路 / Create policy and target networks
policy_net = DQN(state_dim, num_actions).to(device)
target_net = DQN(state_dim, num_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())  # 初始時讓目標網路等於策略網路
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=lr)
memory = ReplayMemory(memory_capacity)
scaler = torch.amp.GradScaler() 

# 載入模型（若有）
if os.path.exists('checkpoint_V9.pth'):
    checkpoint = torch.load('checkpoint_V9.pth', map_location=device)
    policy_net.load_state_dict(checkpoint['policy_net'])
    target_net.load_state_dict(checkpoint['target_net'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    start_episode   = checkpoint['episode'] + 1
    frame_idx       = checkpoint['total_steps']
    best_score      = checkpoint['best_score']
    epsilon         = checkpoint['epsilon']
    reward_history  = checkpoint['reward_history']
    score_history   = checkpoint['score_history']
    print(f"Loaded checkpoint from episode {start_episode}, best score: {best_score:.2f}, epsilon={epsilon:.3f}")
else:
    start_episode = 0
    frame_idx    = 0
    best_score = float('-inf')
    epsilon = epsilon_start
    reward_history = []
    score_history = []


# 訓練迴圈 / Training loop
# 每次可以訓練個100步(根據自己的設備與時間調整)，然後下一次都再接續上次的訓練模型接續往下訓練
# You can train for 100 steps each time (adjust according to your own equipment and time), 
# and then continue training from the last training model next time.
for episode in range(start_episode, 4000): # last time = 3200
    cur_state_b, cur_state = preprocess_state(env.reset(), None, True)  # 回傳 4×84×84
    episode_reward = 0
    # state, stacked_frames = stack_frames(None, state, True)
    done = False

    while not done:
        # ε-greedy 策略：隨機選擇動作或從模型中選擇 / Epsilon-greedy action selection
        # if random.random() < epsilon:
        #     action = random.choice(env.action_space)
        # else:
        #     with torch.no_grad():
        #         state_tensor = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
        #         action = policy_net(state_tensor).argmax(dim=1).item()

        frame_idx += 1
        if random.random() < epsilon:
            action = random.randrange(num_actions)
        else:
            with torch.no_grad():
                q = policy_net(cur_state_b.to(device))
                action = q.argmax(dim=1).item()  # 取得最大 Q 值對應的動作

        # 執行動作 / Perform action
        next_state_raw, reward, done, info = env.step(action)

        next_state_b, next_state = preprocess_state(next_state_raw, cur_state, False)
        # 存入經驗  (去掉 batch 維度)
        memory.push(cur_state.cpu(), action, reward, next_state.cpu(), done)
        cur_state_b, cur_state = next_state_b, next_state
        episode_reward += reward

        # 訓練模型 / Train the model from memory
        if len(memory) >= batch_size:
            for _ in range(1): # 你可以調整這個數字，例如 2 或 4
                states, actions, rewards, next_states, dones = memory.sample(batch_size)
                # states = states.to(device)
                # next_states = next_states.to(device)
                # actions = actions.to(device)
                # rewards = rewards.to(device)
                # dones = dones.to(device)
                states = states.to(device, non_blocking=True)
                next_states = next_states.to(device, non_blocking=True)
                actions = actions.to(device, non_blocking=True)
                rewards = rewards.to(device, non_blocking=True)
                dones = dones.to(device, non_blocking=True)

                with torch.amp.autocast("cuda"):
                    # 計算 Q 值 / Compute Q values
                    q_values = policy_net(states)
                    q_values = q_values.gather(1, actions)  # 取得當前動作的 Q 值

                    # 計算目標 Q 值 / Compute target Q values
                    next_q_values = target_net(next_states).max(1,keepdim = True)[0].detach()
                    expected_q = rewards + (gamma * next_q_values * (1 - dones))

                    loss = F.mse_loss(q_values, expected_q)

                optimizer.zero_grad()
                
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()


        # --- 更新 target_net ---
        if frame_idx % target_update_freq == 0: 
            target_net.load_state_dict(policy_net.state_dict())
        
    epsilon = max(epsilon_end, epsilon * epsilon_decay)

    # 更新 epsilon 並紀錄統計資料 / Decay epsilon and log results
    
    reward_history.append(episode_reward)
    score_history.append(info['score'])
    
    print(f"Episode {episode + 1:3d}, Reward: {episode_reward:7.2f}, Score: {info['score']:7.2f}, Epsilon: {epsilon:5.3f}")

    # 儲存模型（若比目前最佳分數更好，或每 50 回合）
    if (episode + 1) % 50 == 0 or info['score'] > best_score:
        best_score = max(best_score, info['score'])

        torch.save({
            'policy_net': policy_net.state_dict(),
            'target_net': target_net.state_dict(),
            'optimizer': optimizer.state_dict(),
            'epsilon': epsilon,
            'episode': episode,
            'total_steps': frame_idx,
            'best_score': best_score,
            'reward_history': reward_history,
            'score_history': score_history,
        }, 'checkpoint_V9.pth')

        print(f"Checkpoint saved at episode {episode + 1}, best score: {best_score:.2f}")

env.close()
``
# Out:
# C:\Users\Wei\AppData\Local\Temp\ipykernel_41284\883696715.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('checkpoint_V9.pth', map_location=device)
# Loaded checkpoint from episode 1200, best score: 2374.00, epsilon=0.301
# Episode 1201, Reward:  187.40, Score:  278.00, Epsilon: 0.301
# Episode 1202, Reward:  650.40, Score:  590.00, Epsilon: 0.300
# Episode 1203, Reward:  609.00, Score:  510.00, Epsilon: 0.300
# Episode 1204, Reward: -158.20, Score:  100.00, Epsilon: 0.300
# Episode 1205, Reward:  812.30, Score:  664.00, Epsilon: 0.300
# Episode 1206, Reward:  282.30, Score:  306.00, Epsilon: 0.299
# Episode 1207, Reward:  547.40, Score:  490.00, Epsilon: 0.299
# Episode 1208, Reward:  167.10, Score:  268.00, Epsilon: 0.299
# Episode 1209, Reward:   47.40, Score:  212.00, Epsilon: 0.298
# Episode 1210, Reward:  424.60, Score:  432.00, Epsilon: 0.298
# Episode 1211, Reward:  133.00, Score:  254.00, Epsilon: 0.298
# Episode 1212, Reward:   74.20, Score:  230.00, Epsilon: 0.297
# Episode 1213, Reward: 1059.30, Score:  746.00, Epsilon: 0.297
# Episode 1214, Reward:  -58.50, Score:  126.00, Epsilon: 0.297
# Episode 1215, Reward:  -12.10, Score:  158.00, Epsilon: 0.297
# Episode 1216, Reward:  730.70, Score:  578.00, Epsilon: 0.296
# Episode 1217, Reward:   23.40, Score:  194.00, Epsilon: 0.296
# Episode 1218, Reward:  -54.80, Score:  144.00, Epsilon: 0.296
# Episode 1219, Reward: 1439.50, Score:  992.00, Epsilon: 0.295
# Episode 1220, Reward:  265.60, Score:  334.00, Epsilon: 0.295
# Episode 1221, Reward:  142.80, Score:  270.00, Epsilon: 0.295
# Episode 1222, Reward: 1037.20, Score:  750.00, Epsilon: 0.294
# Episode 1223, Reward:  428.80, Score:  424.00, Epsilon: 0.294
# Episode 1224, Reward:  670.50, Score:  534.00, Epsilon: 0.294
# Episode 1225, Reward:  571.70, Score:  504.00, Epsilon: 0.294
# Episode 1226, Reward:  543.10, Score:  470.00, Epsilon: 0.293
# Episode 1227, Reward:  543.20, Score:  464.00, Epsilon: 0.293
# Episode 1228, Reward:  704.80, Score:  606.00, Epsilon: 0.293
# Episode 1229, Reward:  459.70, Score:  440.00, Epsilon: 0.292
# Episode 1230, Reward:  387.20, Score:  398.00, Epsilon: 0.292
# Episode 1231, Reward:  -93.40, Score:  110.00, Epsilon: 0.292
# Episode 1232, Reward: -111.70, Score:  122.00, Epsilon: 0.292
# Episode 1233, Reward:  124.00, Score:  228.00, Epsilon: 0.291
# Episode 1234, Reward:  206.30, Score:  260.00, Epsilon: 0.291
# Episode 1235, Reward:  472.10, Score:  464.00, Epsilon: 0.291
# Episode 1236, Reward:  163.70, Score:  262.00, Epsilon: 0.290
# Episode 1237, Reward: 1288.50, Score:  938.00, Epsilon: 0.290
# Episode 1238, Reward:  683.20, Score:  588.00, Epsilon: 0.290
# Episode 1239, Reward:  874.40, Score:  684.00, Epsilon: 0.289
# Episode 1240, Reward:  238.70, Score:  322.00, Epsilon: 0.289
# Episode 1241, Reward:  -93.10, Score:  130.00, Epsilon: 0.289
# Episode 1242, Reward:  895.10, Score:  648.00, Epsilon: 0.289
# Episode 1243, Reward:  286.30, Score:  334.00, Epsilon: 0.288
# Episode 1244, Reward:  479.70, Score:  430.00, Epsilon: 0.288
# Episode 1245, Reward:  640.90, Score:  556.00, Epsilon: 0.288
# Episode 1246, Reward:  282.70, Score:  326.00, Epsilon: 0.287
# Episode 1247, Reward:  534.50, Score:  504.00, Epsilon: 0.287
# Episode 1248, Reward:  629.60, Score:  524.00, Epsilon: 0.287
# Episode 1249, Reward:   78.00, Score:  234.00, Epsilon: 0.287
# Episode 1250, Reward:  626.00, Score:  562.00, Epsilon: 0.286
# Checkpoint saved at episode 1250, best score: 2374.00
# Episode 1251, Reward:   45.00, Score:  196.00, Epsilon: 0.286
# Episode 1252, Reward:  257.30, Score:  336.00, Epsilon: 0.286
# Episode 1253, Reward:  292.20, Score:  326.00, Epsilon: 0.285
# Episode 1254, Reward:  101.80, Score:  260.00, Epsilon: 0.285
# Episode 1255, Reward:  984.30, Score:  736.00, Epsilon: 0.285
# Episode 1256, Reward:  190.10, Score:  278.00, Epsilon: 0.285
# Episode 1257, Reward:  195.90, Score:  302.00, Epsilon: 0.284
# Episode 1258, Reward:  277.30, Score:  318.00, Epsilon: 0.284
# Episode 1259, Reward:  187.40, Score:  258.00, Epsilon: 0.284
# Episode 1260, Reward:  217.40, Score:  306.00, Epsilon: 0.283
# Episode 1261, Reward:  273.10, Score:  350.00, Epsilon: 0.283
# Episode 1262, Reward:  447.50, Score:  414.00, Epsilon: 0.283
# Episode 1263, Reward:  690.90, Score:  530.00, Epsilon: 0.283
# Episode 1264, Reward:  371.20, Score:  382.00, Epsilon: 0.282
# Episode 1265, Reward:  100.50, Score:  230.00, Epsilon: 0.282
# Episode 1266, Reward:   53.80, Score:  188.00, Epsilon: 0.282
# Episode 1267, Reward:  161.50, Score:  272.00, Epsilon: 0.281
# Episode 1268, Reward:  173.60, Score:  266.00, Epsilon: 0.281
# Episode 1269, Reward:  491.90, Score:  434.00, Epsilon: 0.281
# Episode 1270, Reward:  549.00, Score:  518.00, Epsilon: 0.281
# Episode 1271, Reward:  837.80, Score:  666.00, Epsilon: 0.280
# Episode 1272, Reward:  931.90, Score:  710.00, Epsilon: 0.280
# Episode 1273, Reward:  184.50, Score:  286.00, Epsilon: 0.280
# Episode 1274, Reward:  723.40, Score:  590.00, Epsilon: 0.280
# Episode 1275, Reward:  -15.20, Score:  158.00, Epsilon: 0.279
# Episode 1276, Reward:  361.30, Score:  394.00, Epsilon: 0.279
# Episode 1277, Reward:  608.00, Score:  518.00, Epsilon: 0.279
# Episode 1278, Reward:  366.00, Score:  330.00, Epsilon: 0.278
# Episode 1279, Reward:  208.80, Score:  296.00, Epsilon: 0.278
# Episode 1280, Reward:   51.20, Score:  214.00, Epsilon: 0.278
# Episode 1281, Reward:  626.20, Score:  550.00, Epsilon: 0.278
# Episode 1282, Reward:  238.90, Score:  326.00, Epsilon: 0.277
# Episode 1283, Reward:  139.50, Score:  284.00, Epsilon: 0.277
# Episode 1284, Reward:  446.30, Score:  430.00, Epsilon: 0.277
# Episode 1285, Reward:  442.00, Score:  400.00, Epsilon: 0.276
# Episode 1286, Reward:  810.20, Score:  640.00, Epsilon: 0.276
# Episode 1287, Reward:  253.60, Score:  314.00, Epsilon: 0.276
# Episode 1288, Reward:  956.60, Score:  708.00, Epsilon: 0.276
# Episode 1289, Reward:    3.80, Score:  178.00, Epsilon: 0.275
# Episode 1290, Reward:  315.60, Score:  384.00, Epsilon: 0.275
# Episode 1291, Reward: 1645.70, Score: 1190.00, Epsilon: 0.275
# Episode 1292, Reward:  398.60, Score:  400.00, Epsilon: 0.275
# Episode 1293, Reward:  786.70, Score:  646.00, Epsilon: 0.274
# Episode 1294, Reward: 1130.70, Score:  808.00, Epsilon: 0.274
# Episode 1295, Reward:  436.40, Score:  428.00, Epsilon: 0.274
# Episode 1296, Reward:  207.50, Score:  328.00, Epsilon: 0.273
# Episode 1297, Reward:  199.20, Score:  286.00, Epsilon: 0.273
# Episode 1298, Reward:  116.20, Score:  246.00, Epsilon: 0.273
# Episode 1299, Reward:  107.30, Score:  256.00, Epsilon: 0.273
# Episode 1300, Reward:  898.30, Score:  688.00, Epsilon: 0.272
# Checkpoint saved at episode 1300, best score: 2374.00
# Episode 1301, Reward:  -69.00, Score:  150.00, Epsilon: 0.272
# Episode 1302, Reward:  440.20, Score:  416.00, Epsilon: 0.272
# Episode 1303, Reward:  174.80, Score:  264.00, Epsilon: 0.272
# Episode 1304, Reward:  114.60, Score:  260.00, Epsilon: 0.271
# Episode 1305, Reward:  167.60, Score:  278.00, Epsilon: 0.271
# Episode 1306, Reward:  712.60, Score:  540.00, Epsilon: 0.271
# Episode 1307, Reward:  500.90, Score:  488.00, Epsilon: 0.270
# Episode 1308, Reward:  361.90, Score:  378.00, Epsilon: 0.270
# Episode 1309, Reward:  499.80, Score:  500.00, Epsilon: 0.270
# Episode 1310, Reward:  -15.50, Score:  178.00, Epsilon: 0.270
# Episode 1311, Reward:  506.00, Score:  478.00, Epsilon: 0.269
# Episode 1312, Reward:  157.80, Score:  266.00, Epsilon: 0.269
# Episode 1313, Reward: 1263.80, Score:  926.00, Epsilon: 0.269
# Episode 1314, Reward:  218.80, Score:  304.00, Epsilon: 0.269
# Episode 1315, Reward:   73.60, Score:  230.00, Epsilon: 0.268
# Episode 1316, Reward:  -62.00, Score:  120.00, Epsilon: 0.268
# Episode 1317, Reward:  299.00, Score:  346.00, Epsilon: 0.268
# Episode 1318, Reward: 2006.10, Score: 1332.00, Epsilon: 0.267
# Episode 1319, Reward:  183.50, Score:  266.00, Epsilon: 0.267
# Episode 1320, Reward:  775.10, Score:  588.00, Epsilon: 0.267
# Episode 1321, Reward:  532.70, Score:  512.00, Epsilon: 0.267
# Episode 1322, Reward:  297.10, Score:  346.00, Epsilon: 0.266
# Episode 1323, Reward:  217.70, Score:  300.00, Epsilon: 0.266
# Episode 1324, Reward:  485.20, Score:  466.00, Epsilon: 0.266
# Episode 1325, Reward:  141.70, Score:  286.00, Epsilon: 0.266
# Episode 1326, Reward:  314.90, Score:  344.00, Epsilon: 0.265
# Episode 1327, Reward:  608.40, Score:  500.00, Epsilon: 0.265
# Episode 1328, Reward:  275.20, Score:  316.00, Epsilon: 0.265
# Episode 1329, Reward:   97.00, Score:  222.00, Epsilon: 0.265
# Episode 1330, Reward:  108.90, Score:  230.00, Epsilon: 0.264
# Episode 1331, Reward:   83.60, Score:  210.00, Epsilon: 0.264
# Episode 1332, Reward:  120.40, Score:  244.00, Epsilon: 0.264
# Episode 1333, Reward:  409.40, Score:  386.00, Epsilon: 0.264
# Episode 1334, Reward:  319.50, Score:  386.00, Epsilon: 0.263
# Episode 1335, Reward:  468.80, Score:  430.00, Epsilon: 0.263
# Episode 1336, Reward:  180.80, Score:  292.00, Epsilon: 0.263
# Episode 1337, Reward: 2277.00, Score: 1514.00, Epsilon: 0.262
# Episode 1338, Reward:  343.40, Score:  366.00, Epsilon: 0.262
# Episode 1339, Reward:  145.90, Score:  216.00, Epsilon: 0.262
# Episode 1340, Reward:  159.20, Score:  290.00, Epsilon: 0.262
# Episode 1341, Reward:  189.00, Score:  266.00, Epsilon: 0.261
# Episode 1342, Reward:  724.60, Score:  590.00, Epsilon: 0.261
# Episode 1343, Reward:  391.90, Score:  382.00, Epsilon: 0.261
# Episode 1344, Reward:   34.30, Score:  210.00, Epsilon: 0.261
# Episode 1345, Reward:  818.40, Score:  618.00, Epsilon: 0.260
# Episode 1346, Reward:  546.60, Score:  502.00, Epsilon: 0.260
# Episode 1347, Reward:   13.00, Score:  176.00, Epsilon: 0.260
# Episode 1348, Reward:  145.30, Score:  268.00, Epsilon: 0.260
# Episode 1349, Reward:  432.40, Score:  398.00, Epsilon: 0.259
# Episode 1350, Reward:  123.80, Score:  252.00, Epsilon: 0.259
# Checkpoint saved at episode 1350, best score: 2374.00
# Episode 1351, Reward:  626.20, Score:  520.00, Epsilon: 0.259
# Episode 1352, Reward:  944.50, Score:  734.00, Epsilon: 0.259
# Episode 1353, Reward: 1491.50, Score: 1074.00, Epsilon: 0.258
# Episode 1354, Reward:  379.80, Score:  382.00, Epsilon: 0.258
# Episode 1355, Reward:  135.20, Score:  230.00, Epsilon: 0.258
# Episode 1356, Reward:  151.00, Score:  232.00, Epsilon: 0.258
# Episode 1357, Reward:  307.20, Score:  362.00, Epsilon: 0.257
# Episode 1358, Reward: 1028.30, Score:  712.00, Epsilon: 0.257
# Episode 1359, Reward:   60.80, Score:  220.00, Epsilon: 0.257
# Episode 1360, Reward:  132.30, Score:  256.00, Epsilon: 0.256
# Episode 1361, Reward:  523.90, Score:  478.00, Epsilon: 0.256
# Episode 1362, Reward:  527.20, Score:  502.00, Epsilon: 0.256
# Episode 1363, Reward:  321.40, Score:  380.00, Epsilon: 0.256
# Episode 1364, Reward:  679.60, Score:  568.00, Epsilon: 0.255
# Episode 1365, Reward: -156.70, Score:  102.00, Epsilon: 0.255
# Episode 1366, Reward:  818.00, Score:  636.00, Epsilon: 0.255
# Episode 1367, Reward: -190.50, Score:   78.00, Epsilon: 0.255
# Episode 1368, Reward:  308.00, Score:  324.00, Epsilon: 0.254
# Episode 1369, Reward:  847.20, Score:  722.00, Epsilon: 0.254
# Episode 1370, Reward:   93.80, Score:  244.00, Epsilon: 0.254
# Episode 1371, Reward:   39.70, Score:  218.00, Epsilon: 0.254
# Episode 1372, Reward:   59.90, Score:  216.00, Epsilon: 0.253
# Episode 1373, Reward:  136.20, Score:  256.00, Epsilon: 0.253
# Episode 1374, Reward:   75.10, Score:  234.00, Epsilon: 0.253
# Episode 1375, Reward:   89.10, Score:  234.00, Epsilon: 0.253
# Episode 1376, Reward:  220.30, Score:  290.00, Epsilon: 0.252
# Episode 1377, Reward:  245.30, Score:  330.00, Epsilon: 0.252
# Episode 1378, Reward:  773.70, Score:  604.00, Epsilon: 0.252
# Episode 1379, Reward:  145.60, Score:  264.00, Epsilon: 0.252
# Episode 1380, Reward:  688.60, Score:  580.00, Epsilon: 0.251
# Episode 1381, Reward:  733.30, Score:  562.00, Epsilon: 0.251
# Episode 1382, Reward:   12.10, Score:  194.00, Epsilon: 0.251
# Episode 1383, Reward:  830.90, Score:  668.00, Epsilon: 0.251
# Episode 1384, Reward:  637.80, Score:  504.00, Epsilon: 0.250
# Episode 1385, Reward:  729.90, Score:  584.00, Epsilon: 0.250
# Episode 1386, Reward:  191.10, Score:  306.00, Epsilon: 0.250
# Episode 1387, Reward:  738.30, Score:  618.00, Epsilon: 0.250
# Episode 1388, Reward:  168.60, Score:  268.00, Epsilon: 0.249
# Episode 1389, Reward:  615.00, Score:  514.00, Epsilon: 0.249
# Episode 1390, Reward:  121.20, Score:  250.00, Epsilon: 0.249
# Episode 1391, Reward:  192.00, Score:  290.00, Epsilon: 0.249
# Episode 1392, Reward: -144.10, Score:  120.00, Epsilon: 0.248
# Episode 1393, Reward:   62.00, Score:  218.00, Epsilon: 0.248
# Episode 1394, Reward:  130.30, Score:  268.00, Epsilon: 0.248
# Episode 1395, Reward:  404.30, Score:  414.00, Epsilon: 0.248
# Episode 1396, Reward:  160.80, Score:  268.00, Epsilon: 0.247
# Episode 1397, Reward:  642.90, Score:  576.00, Epsilon: 0.247
# Episode 1398, Reward:  190.00, Score:  312.00, Epsilon: 0.247
# Episode 1399, Reward:   94.40, Score:  238.00, Epsilon: 0.247
# Episode 1400, Reward:  170.60, Score:  298.00, Epsilon: 0.246
# Checkpoint saved at episode 1400, best score: 2374.00
# Episode 1401, Reward:  842.20, Score:  688.00, Epsilon: 0.246
# Episode 1402, Reward:  817.60, Score:  672.00, Epsilon: 0.246
# Episode 1403, Reward:   38.60, Score:  192.00, Epsilon: 0.246
# Episode 1404, Reward:  216.10, Score:  292.00, Epsilon: 0.245
# Episode 1405, Reward:  334.90, Score:  372.00, Epsilon: 0.245
# Episode 1406, Reward:  307.80, Score:  366.00, Epsilon: 0.245
# Episode 1407, Reward:  495.80, Score:  470.00, Epsilon: 0.245
# Episode 1408, Reward: 1222.40, Score:  868.00, Epsilon: 0.244
# Episode 1409, Reward:   48.00, Score:  198.00, Epsilon: 0.244
# Episode 1410, Reward:  431.00, Score:  394.00, Epsilon: 0.244
# Episode 1411, Reward:  272.80, Score:  346.00, Epsilon: 0.244
# Episode 1412, Reward:  -61.90, Score:  146.00, Epsilon: 0.243
# Episode 1413, Reward:  285.50, Score:  352.00, Epsilon: 0.243
# Episode 1414, Reward:   54.00, Score:  222.00, Epsilon: 0.243
# Episode 1415, Reward:  602.90, Score:  520.00, Epsilon: 0.243
# Episode 1416, Reward:  164.40, Score:  228.00, Epsilon: 0.243
# Episode 1417, Reward:  903.50, Score:  682.00, Epsilon: 0.242
# Episode 1418, Reward:  109.50, Score:  214.00, Epsilon: 0.242
# Episode 1419, Reward:  229.50, Score:  306.00, Epsilon: 0.242
# Episode 1420, Reward:  604.20, Score:  484.00, Epsilon: 0.242
# Episode 1421, Reward:   22.70, Score:  210.00, Epsilon: 0.241
# Episode 1422, Reward:  624.60, Score:  546.00, Epsilon: 0.241
# Episode 1423, Reward:  122.10, Score:  270.00, Epsilon: 0.241
# Episode 1424, Reward:  431.70, Score:  400.00, Epsilon: 0.241
# Episode 1425, Reward:  263.30, Score:  324.00, Epsilon: 0.240
# Episode 1426, Reward:   27.00, Score:  204.00, Epsilon: 0.240
# Episode 1427, Reward:   60.20, Score:  216.00, Epsilon: 0.240
# Episode 1428, Reward:  481.40, Score:  474.00, Epsilon: 0.240
# Episode 1429, Reward:  508.90, Score:  482.00, Epsilon: 0.239
# Episode 1430, Reward:  193.80, Score:  268.00, Epsilon: 0.239
# Episode 1431, Reward:  521.00, Score:  490.00, Epsilon: 0.239
# Episode 1432, Reward: 1594.60, Score: 1134.00, Epsilon: 0.239
# Episode 1433, Reward:  324.70, Score:  362.00, Epsilon: 0.238
# Episode 1434, Reward:  321.50, Score:  342.00, Epsilon: 0.238
# Episode 1435, Reward:  539.60, Score:  518.00, Epsilon: 0.238
# Episode 1436, Reward:  122.10, Score:  246.00, Epsilon: 0.238
# Episode 1437, Reward:  978.60, Score:  742.00, Epsilon: 0.237
# Episode 1438, Reward:  553.20, Score:  462.00, Epsilon: 0.237
# Episode 1439, Reward:  665.60, Score:  540.00, Epsilon: 0.237
# Episode 1440, Reward:  849.40, Score:  644.00, Epsilon: 0.237
# Episode 1441, Reward: 1108.60, Score:  826.00, Epsilon: 0.237
# Episode 1442, Reward:  399.20, Score:  384.00, Epsilon: 0.236
# Episode 1443, Reward: -112.70, Score:  124.00, Epsilon: 0.236
# Episode 1444, Reward:  894.20, Score:  678.00, Epsilon: 0.236
# Episode 1445, Reward:  211.70, Score:  310.00, Epsilon: 0.236
# Episode 1446, Reward:  494.20, Score:  490.00, Epsilon: 0.235
# Episode 1447, Reward:  567.20, Score:  464.00, Epsilon: 0.235
# Episode 1448, Reward:  212.90, Score:  298.00, Epsilon: 0.235
# Episode 1449, Reward:  137.70, Score:  236.00, Epsilon: 0.235
# Episode 1450, Reward:  405.30, Score:  396.00, Epsilon: 0.234
# Checkpoint saved at episode 1450, best score: 2374.00
# Episode 1451, Reward:  148.70, Score:  264.00, Epsilon: 0.234
# Episode 1452, Reward: 1621.10, Score: 1056.00, Epsilon: 0.234
# Episode 1453, Reward:  429.30, Score:  444.00, Epsilon: 0.234
# Episode 1454, Reward:  188.60, Score:  270.00, Epsilon: 0.233
# Episode 1455, Reward:  -65.30, Score:  142.00, Epsilon: 0.233
# Episode 1456, Reward:  409.10, Score:  446.00, Epsilon: 0.233
# Episode 1457, Reward:   -3.60, Score:  204.00, Epsilon: 0.233
# Episode 1458, Reward:  -86.50, Score:  104.00, Epsilon: 0.233
# Episode 1459, Reward:  763.40, Score:  610.00, Epsilon: 0.232
# Episode 1460, Reward:   72.90, Score:  228.00, Epsilon: 0.232
# Episode 1461, Reward:  141.20, Score:  264.00, Epsilon: 0.232
# Episode 1462, Reward:  418.00, Score:  416.00, Epsilon: 0.232
# Episode 1463, Reward:   20.40, Score:  196.00, Epsilon: 0.231
# Episode 1464, Reward:  145.20, Score:  270.00, Epsilon: 0.231
# Episode 1465, Reward:  453.70, Score:  448.00, Epsilon: 0.231
# Episode 1466, Reward:   59.40, Score:  196.00, Epsilon: 0.231
# Episode 1467, Reward:  171.50, Score:  270.00, Epsilon: 0.230
# Episode 1468, Reward:  -18.30, Score:  178.00, Epsilon: 0.230
# Episode 1469, Reward:  527.70, Score:  450.00, Epsilon: 0.230
# Episode 1470, Reward:  -17.20, Score:  168.00, Epsilon: 0.230
# Episode 1471, Reward:   -2.80, Score:  176.00, Epsilon: 0.230
# Episode 1472, Reward:  560.00, Score:  512.00, Epsilon: 0.229
# Episode 1473, Reward:   85.40, Score:  260.00, Epsilon: 0.229
# Episode 1474, Reward:  648.60, Score:  556.00, Epsilon: 0.229
# Episode 1475, Reward:  -82.60, Score:  152.00, Epsilon: 0.229
# Episode 1476, Reward:  307.90, Score:  370.00, Epsilon: 0.228
# Episode 1477, Reward:  106.60, Score:  266.00, Epsilon: 0.228
# Episode 1478, Reward:  144.70, Score:  260.00, Epsilon: 0.228
# Episode 1479, Reward:  483.10, Score:  462.00, Epsilon: 0.228
# Episode 1480, Reward:   55.30, Score:  202.00, Epsilon: 0.227
# Episode 1481, Reward:  644.50, Score:  578.00, Epsilon: 0.227
# Episode 1482, Reward:   83.30, Score:  246.00, Epsilon: 0.227
# Episode 1483, Reward:  145.70, Score:  244.00, Epsilon: 0.227
# Episode 1484, Reward:  -23.90, Score:  162.00, Epsilon: 0.227
# Episode 1485, Reward:   50.00, Score:  202.00, Epsilon: 0.226
# Episode 1486, Reward:  170.30, Score:  262.00, Epsilon: 0.226
# Episode 1487, Reward: -109.40, Score:  126.00, Epsilon: 0.226
# Episode 1488, Reward:   96.90, Score:  246.00, Epsilon: 0.226
# Episode 1489, Reward:  282.70, Score:  338.00, Epsilon: 0.225
# Episode 1490, Reward:  883.20, Score:  684.00, Epsilon: 0.225
# Episode 1491, Reward:  796.50, Score:  590.00, Epsilon: 0.225
# Episode 1492, Reward:  393.90, Score:  398.00, Epsilon: 0.225
# Episode 1493, Reward:  899.50, Score:  730.00, Epsilon: 0.225
# Episode 1494, Reward:  -76.80, Score:  144.00, Epsilon: 0.224
# Episode 1495, Reward:  772.00, Score:  594.00, Epsilon: 0.224
# Episode 1496, Reward:   32.90, Score:  194.00, Epsilon: 0.224
# Episode 1497, Reward:  -33.70, Score:  152.00, Epsilon: 0.224
# Episode 1498, Reward:  493.40, Score:  478.00, Epsilon: 0.223
# Episode 1499, Reward:  489.30, Score:  452.00, Epsilon: 0.223
# Episode 1500, Reward:   25.60, Score:  196.00, Epsilon: 0.223
# Checkpoint saved at episode 1500, best score: 2374.00
# Episode 1501, Reward:   89.30, Score:  250.00, Epsilon: 0.223
# Episode 1502, Reward:  611.30, Score:  516.00, Epsilon: 0.223
# Episode 1503, Reward:  643.00, Score:  548.00, Epsilon: 0.222
# Episode 1504, Reward: 1084.40, Score:  806.00, Epsilon: 0.222
# Episode 1505, Reward:  204.00, Score:  296.00, Epsilon: 0.222
# Episode 1506, Reward:  313.70, Score:  368.00, Epsilon: 0.222
# Episode 1507, Reward:  926.70, Score:  714.00, Epsilon: 0.221
# Episode 1508, Reward:  326.50, Score:  392.00, Epsilon: 0.221
# Episode 1509, Reward:  268.70, Score:  316.00, Epsilon: 0.221
# Episode 1510, Reward:  257.90, Score:  322.00, Epsilon: 0.221
# Episode 1511, Reward:  121.40, Score:  258.00, Epsilon: 0.221
# Episode 1512, Reward:  456.40, Score:  424.00, Epsilon: 0.220
# Episode 1513, Reward:   88.20, Score:  236.00, Epsilon: 0.220
# Episode 1514, Reward:  403.70, Score:  414.00, Epsilon: 0.220
# Episode 1515, Reward:  156.80, Score:  260.00, Epsilon: 0.220
# Episode 1516, Reward:  179.70, Score:  302.00, Epsilon: 0.219
# Episode 1517, Reward:  270.40, Score:  346.00, Epsilon: 0.219
# Episode 1518, Reward:  226.20, Score:  310.00, Epsilon: 0.219
# Episode 1519, Reward:   12.00, Score:  166.00, Epsilon: 0.219
# Episode 1520, Reward: -107.90, Score:  110.00, Epsilon: 0.219
# Episode 1521, Reward:   94.20, Score:  228.00, Epsilon: 0.218
# Episode 1522, Reward:  112.80, Score:  240.00, Epsilon: 0.218
# Episode 1523, Reward:  309.10, Score:  352.00, Epsilon: 0.218
# Episode 1524, Reward:  310.80, Score:  368.00, Epsilon: 0.218
# Episode 1525, Reward:  648.20, Score:  524.00, Epsilon: 0.217
# Episode 1526, Reward:  181.40, Score:  286.00, Epsilon: 0.217
# Episode 1527, Reward:  -32.70, Score:  170.00, Epsilon: 0.217
# Episode 1528, Reward:  139.50, Score:  256.00, Epsilon: 0.217
# Episode 1529, Reward:  183.50, Score:  302.00, Epsilon: 0.217
# Episode 1530, Reward:  410.00, Score:  430.00, Epsilon: 0.216
# Episode 1531, Reward:  313.40, Score:  370.00, Epsilon: 0.216
# Episode 1532, Reward:  483.60, Score:  442.00, Epsilon: 0.216
# Episode 1533, Reward:  597.00, Score:  522.00, Epsilon: 0.216
# Episode 1534, Reward:  550.60, Score:  462.00, Epsilon: 0.216
# Episode 1535, Reward:  163.10, Score:  256.00, Epsilon: 0.215
# Episode 1536, Reward:  349.70, Score:  364.00, Epsilon: 0.215
# Episode 1537, Reward:  624.50, Score:  532.00, Epsilon: 0.215
# Episode 1538, Reward:  303.00, Score:  372.00, Epsilon: 0.215
# Episode 1539, Reward:  249.80, Score:  300.00, Epsilon: 0.214
# Episode 1540, Reward:  390.60, Score:  370.00, Epsilon: 0.214
# Episode 1541, Reward:  771.00, Score:  638.00, Epsilon: 0.214
# Episode 1542, Reward:  210.20, Score:  278.00, Epsilon: 0.214
# Episode 1543, Reward:  466.90, Score:  422.00, Epsilon: 0.214
# Episode 1544, Reward:  141.80, Score:  266.00, Epsilon: 0.213
# Episode 1545, Reward:  -66.30, Score:  132.00, Epsilon: 0.213
# Episode 1546, Reward:  370.70, Score:  350.00, Epsilon: 0.213
# Episode 1547, Reward:  838.40, Score:  688.00, Epsilon: 0.213
# Episode 1548, Reward:  157.20, Score:  270.00, Epsilon: 0.213
# Episode 1549, Reward:  262.20, Score:  330.00, Epsilon: 0.212
# Episode 1550, Reward:  604.60, Score:  526.00, Epsilon: 0.212
# Checkpoint saved at episode 1550, best score: 2374.00
# Episode 1551, Reward:   57.30, Score:  210.00, Epsilon: 0.212
# Episode 1552, Reward:  889.40, Score:  656.00, Epsilon: 0.212
# Episode 1553, Reward:  417.60, Score:  412.00, Epsilon: 0.211
# Episode 1554, Reward:  278.90, Score:  290.00, Epsilon: 0.211
# Episode 1555, Reward:  -45.90, Score:  122.00, Epsilon: 0.211
# Episode 1556, Reward:  384.80, Score:  410.00, Epsilon: 0.211
# Episode 1557, Reward:  184.70, Score:  260.00, Epsilon: 0.211
# Episode 1558, Reward:  417.40, Score:  430.00, Epsilon: 0.210
# Episode 1559, Reward:  359.60, Score:  356.00, Epsilon: 0.210
# Episode 1560, Reward:   96.70, Score:  240.00, Epsilon: 0.210
# Episode 1561, Reward:  975.40, Score:  752.00, Epsilon: 0.210
# Episode 1562, Reward:  265.80, Score:  324.00, Epsilon: 0.210
# Episode 1563, Reward:  338.00, Score:  386.00, Epsilon: 0.209
# Episode 1564, Reward:  288.60, Score:  318.00, Epsilon: 0.209
# Episode 1565, Reward:  340.60, Score:  338.00, Epsilon: 0.209
# Episode 1566, Reward:   38.50, Score:  212.00, Epsilon: 0.209
# Episode 1567, Reward:  -16.00, Score:  166.00, Epsilon: 0.209
# Episode 1568, Reward:  108.60, Score:  222.00, Epsilon: 0.208
# Episode 1569, Reward:   50.40, Score:  210.00, Epsilon: 0.208
# Episode 1570, Reward:  203.40, Score:  300.00, Epsilon: 0.208
# Episode 1571, Reward: 1561.20, Score: 1076.00, Epsilon: 0.208
# Episode 1572, Reward:  113.30, Score:  236.00, Epsilon: 0.207
# Episode 1573, Reward:  164.20, Score:  284.00, Epsilon: 0.207
# Episode 1574, Reward:   60.90, Score:  244.00, Epsilon: 0.207
# Episode 1575, Reward:  533.40, Score:  480.00, Epsilon: 0.207
# Episode 1576, Reward:  533.40, Score:  502.00, Epsilon: 0.207
# Episode 1577, Reward:  -11.50, Score:  158.00, Epsilon: 0.206
# Episode 1578, Reward: -146.80, Score:  104.00, Epsilon: 0.206
# Episode 1579, Reward:  548.40, Score:  440.00, Epsilon: 0.206
# Episode 1580, Reward:   41.70, Score:  204.00, Epsilon: 0.206
# Episode 1581, Reward:  429.60, Score:  426.00, Epsilon: 0.206
# Episode 1582, Reward:  124.70, Score:  246.00, Epsilon: 0.205
# Episode 1583, Reward:  506.70, Score:  456.00, Epsilon: 0.205
# Episode 1584, Reward:   54.30, Score:  186.00, Epsilon: 0.205
# Episode 1585, Reward:   91.00, Score:  234.00, Epsilon: 0.205
# Episode 1586, Reward:  260.80, Score:  292.00, Epsilon: 0.205
# Episode 1587, Reward:  235.60, Score:  318.00, Epsilon: 0.204
# Episode 1588, Reward:  671.10, Score:  586.00, Epsilon: 0.204
# Episode 1589, Reward:  586.40, Score:  518.00, Epsilon: 0.204
# Episode 1590, Reward:  886.60, Score:  726.00, Epsilon: 0.204
# Episode 1591, Reward:   72.50, Score:  232.00, Epsilon: 0.204
# Episode 1592, Reward:  326.40, Score:  384.00, Epsilon: 0.203
# Episode 1593, Reward:   64.10, Score:  226.00, Epsilon: 0.203
# Episode 1594, Reward:  464.30, Score:  444.00, Epsilon: 0.203
# Episode 1595, Reward:  246.60, Score:  334.00, Epsilon: 0.203
# Episode 1596, Reward:  771.40, Score:  610.00, Epsilon: 0.203
# Episode 1597, Reward:  -33.00, Score:  162.00, Epsilon: 0.202
# Episode 1598, Reward:    4.90, Score:  196.00, Epsilon: 0.202
# Episode 1599, Reward:  194.90, Score:  296.00, Epsilon: 0.202
# Episode 1600, Reward:  422.30, Score:  440.00, Epsilon: 0.202
# Checkpoint saved at episode 1600, best score: 2374.00
# Episode 1601, Reward:  -42.40, Score:  174.00, Epsilon: 0.202
# Episode 1602, Reward:  359.50, Score:  392.00, Epsilon: 0.201
# Episode 1603, Reward:  196.10, Score:  290.00, Epsilon: 0.201
# Episode 1604, Reward:  284.20, Score:  330.00, Epsilon: 0.201
# Episode 1605, Reward:  739.80, Score:  596.00, Epsilon: 0.201
# Episode 1606, Reward:  275.30, Score:  336.00, Epsilon: 0.201
# Episode 1607, Reward:  196.60, Score:  304.00, Epsilon: 0.200
# Episode 1608, Reward:  206.40, Score:  284.00, Epsilon: 0.200
# Episode 1609, Reward:  152.70, Score:  256.00, Epsilon: 0.200
# Episode 1610, Reward:  538.20, Score:  452.00, Epsilon: 0.200
# Episode 1611, Reward:  138.20, Score:  218.00, Epsilon: 0.200
# Episode 1612, Reward:  203.00, Score:  308.00, Epsilon: 0.199
# Episode 1613, Reward:  163.20, Score:  252.00, Epsilon: 0.199
# Episode 1614, Reward:  -90.90, Score:  142.00, Epsilon: 0.199
# Episode 1615, Reward:  494.20, Score:  490.00, Epsilon: 0.199
# Episode 1616, Reward:  269.00, Score:  316.00, Epsilon: 0.199
# Episode 1617, Reward:  145.80, Score:  254.00, Epsilon: 0.198
# Episode 1618, Reward:  641.10, Score:  564.00, Epsilon: 0.198
# Episode 1619, Reward:  183.90, Score:  266.00, Epsilon: 0.198
# Episode 1620, Reward:  542.20, Score:  516.00, Epsilon: 0.198
# Episode 1621, Reward:  220.50, Score:  272.00, Epsilon: 0.198
# Episode 1622, Reward:   78.20, Score:  222.00, Epsilon: 0.197
# Episode 1623, Reward:  589.60, Score:  532.00, Epsilon: 0.197
# Episode 1624, Reward:  605.60, Score:  542.00, Epsilon: 0.197
# Episode 1625, Reward:  481.00, Score:  474.00, Epsilon: 0.197
# Episode 1626, Reward:  484.10, Score:  458.00, Epsilon: 0.197
# Episode 1627, Reward:   78.20, Score:  232.00, Epsilon: 0.196
# Episode 1628, Reward:  634.60, Score:  550.00, Epsilon: 0.196
# Episode 1629, Reward:  224.80, Score:  320.00, Epsilon: 0.196
# Episode 1630, Reward: 1103.20, Score:  850.00, Epsilon: 0.196
# Episode 1631, Reward:   -7.50, Score:  174.00, Epsilon: 0.196
# Episode 1632, Reward: -156.80, Score:  102.00, Epsilon: 0.195
# Episode 1633, Reward:  -45.60, Score:  152.00, Epsilon: 0.195
# Episode 1634, Reward:  127.00, Score:  256.00, Epsilon: 0.195
# Episode 1635, Reward:  257.70, Score:  328.00, Epsilon: 0.195
# Episode 1636, Reward:  270.40, Score:  316.00, Epsilon: 0.195
# Episode 1637, Reward:  108.00, Score:  244.00, Epsilon: 0.194
# Episode 1638, Reward:  801.50, Score:  658.00, Epsilon: 0.194
# Episode 1639, Reward:  793.80, Score:  626.00, Epsilon: 0.194
# Episode 1640, Reward:   38.40, Score:  218.00, Epsilon: 0.194
# Episode 1641, Reward:   48.40, Score:  208.00, Epsilon: 0.194
# Episode 1642, Reward:  345.50, Score:  416.00, Epsilon: 0.193
# Episode 1643, Reward:  261.50, Score:  332.00, Epsilon: 0.193
# Episode 1644, Reward:  256.40, Score:  336.00, Epsilon: 0.193
# Episode 1645, Reward:   21.10, Score:  194.00, Epsilon: 0.193
# Episode 1646, Reward:  518.90, Score:  454.00, Epsilon: 0.193
# Episode 1647, Reward:   25.70, Score:  192.00, Epsilon: 0.192
# Episode 1648, Reward:  100.00, Score:  218.00, Epsilon: 0.192
# Episode 1649, Reward:  391.00, Score:  386.00, Epsilon: 0.192
# Episode 1650, Reward:  210.70, Score:  306.00, Epsilon: 0.192
# Checkpoint saved at episode 1650, best score: 2374.00
# Episode 1651, Reward:  101.10, Score:  244.00, Epsilon: 0.192
# Episode 1652, Reward:  346.30, Score:  328.00, Epsilon: 0.192
# Episode 1653, Reward:  259.90, Score:  294.00, Epsilon: 0.191
# Episode 1654, Reward:  524.20, Score:  484.00, Epsilon: 0.191
# Episode 1655, Reward:  195.10, Score:  308.00, Epsilon: 0.191
# Episode 1656, Reward:  430.90, Score:  430.00, Epsilon: 0.191
# Episode 1657, Reward:  254.10, Score:  352.00, Epsilon: 0.191
# Episode 1658, Reward:  272.30, Score:  302.00, Epsilon: 0.190
# Episode 1659, Reward:  145.80, Score:  256.00, Epsilon: 0.190
# Episode 1660, Reward:  111.40, Score:  254.00, Epsilon: 0.190
# Episode 1661, Reward:  246.70, Score:  328.00, Epsilon: 0.190
# Episode 1662, Reward:  438.00, Score:  418.00, Epsilon: 0.190
# Episode 1663, Reward:  205.40, Score:  302.00, Epsilon: 0.189
# Episode 1664, Reward:  264.50, Score:  330.00, Epsilon: 0.189
# Episode 1665, Reward:  -47.40, Score:  160.00, Epsilon: 0.189
# Episode 1666, Reward:  110.90, Score:  222.00, Epsilon: 0.189
# Episode 1667, Reward:  -95.00, Score:  134.00, Epsilon: 0.189
# Episode 1668, Reward: -112.30, Score:  118.00, Epsilon: 0.188
# Episode 1669, Reward:  142.70, Score:  284.00, Epsilon: 0.188
# Episode 1670, Reward:  151.60, Score:  254.00, Epsilon: 0.188
# Episode 1671, Reward:  443.30, Score:  424.00, Epsilon: 0.188
# Episode 1672, Reward:  876.40, Score:  692.00, Epsilon: 0.188
# Episode 1673, Reward:  117.90, Score:  260.00, Epsilon: 0.188
# Episode 1674, Reward: -178.60, Score:   62.00, Epsilon: 0.187
# Episode 1675, Reward:   53.20, Score:  194.00, Epsilon: 0.187
# Episode 1676, Reward:  251.00, Score:  302.00, Epsilon: 0.187
# Episode 1677, Reward:   93.70, Score:  260.00, Epsilon: 0.187
# Episode 1678, Reward:  726.00, Score:  590.00, Epsilon: 0.187
# Episode 1679, Reward:   61.00, Score:  194.00, Epsilon: 0.186
# Episode 1680, Reward:  567.30, Score:  522.00, Epsilon: 0.186
# Episode 1681, Reward:  540.60, Score:  480.00, Epsilon: 0.186
# Episode 1682, Reward:  316.40, Score:  384.00, Epsilon: 0.186
# Episode 1683, Reward: -210.20, Score:   54.00, Epsilon: 0.186
# Episode 1684, Reward:   45.40, Score:  220.00, Epsilon: 0.185
# Episode 1685, Reward: 1129.10, Score:  836.00, Epsilon: 0.185
# Episode 1686, Reward:  383.00, Score:  390.00, Epsilon: 0.185
# Episode 1687, Reward:  417.30, Score:  382.00, Epsilon: 0.185
# Episode 1688, Reward:  451.60, Score:  450.00, Epsilon: 0.185
# Episode 1689, Reward:  139.30, Score:  272.00, Epsilon: 0.185
# Episode 1690, Reward:  319.30, Score:  332.00, Epsilon: 0.184
# Episode 1691, Reward:  712.90, Score:  520.00, Epsilon: 0.184
# Episode 1692, Reward:  900.90, Score:  698.00, Epsilon: 0.184
# Episode 1693, Reward:  148.70, Score:  262.00, Epsilon: 0.184
# Episode 1694, Reward:  348.40, Score:  366.00, Epsilon: 0.184
# Episode 1695, Reward:  -34.60, Score:  142.00, Epsilon: 0.183
# Episode 1696, Reward:    7.00, Score:  192.00, Epsilon: 0.183
# Episode 1697, Reward:  971.20, Score:  754.00, Epsilon: 0.183
# Episode 1698, Reward:  -59.90, Score:  138.00, Epsilon: 0.183
# Episode 1699, Reward: 1101.70, Score:  808.00, Epsilon: 0.183
# Episode 1700, Reward: -113.00, Score:  134.00, Epsilon: 0.183
# Checkpoint saved at episode 1700, best score: 2374.00
# Episode 1701, Reward:  137.10, Score:  278.00, Epsilon: 0.182
# Episode 1702, Reward:  113.50, Score:  248.00, Epsilon: 0.182
# Episode 1703, Reward:   44.90, Score:  214.00, Epsilon: 0.182
# Episode 1704, Reward:  500.90, Score:  458.00, Epsilon: 0.182
# Episode 1705, Reward:  580.70, Score:  524.00, Epsilon: 0.182
# Episode 1706, Reward:  247.80, Score:  330.00, Epsilon: 0.181
# Episode 1707, Reward:  226.40, Score:  338.00, Epsilon: 0.181
# Episode 1708, Reward:  -56.10, Score:  144.00, Epsilon: 0.181
# Episode 1709, Reward:  195.70, Score:  286.00, Epsilon: 0.181
# Episode 1710, Reward:  586.30, Score:  518.00, Epsilon: 0.181
# Episode 1711, Reward:   80.30, Score:  236.00, Epsilon: 0.181
# Episode 1712, Reward:  311.90, Score:  336.00, Epsilon: 0.180
# Episode 1713, Reward:  689.20, Score:  568.00, Epsilon: 0.180
# Episode 1714, Reward:  249.40, Score:  300.00, Epsilon: 0.180
# Episode 1715, Reward:  374.00, Score:  406.00, Epsilon: 0.180
# Episode 1716, Reward:  333.80, Score:  358.00, Epsilon: 0.180
# Episode 1717, Reward:  318.60, Score:  366.00, Epsilon: 0.179
# Episode 1718, Reward:  713.50, Score:  610.00, Epsilon: 0.179
# Episode 1719, Reward:  230.90, Score:  328.00, Epsilon: 0.179
# Episode 1720, Reward:   76.90, Score:  232.00, Epsilon: 0.179
# Episode 1721, Reward:  491.30, Score:  426.00, Epsilon: 0.179
# Episode 1722, Reward: 1189.00, Score:  854.00, Epsilon: 0.179
# Episode 1723, Reward:  148.50, Score:  258.00, Epsilon: 0.178
# Episode 1724, Reward:  266.40, Score:  344.00, Epsilon: 0.178
# Episode 1725, Reward:   53.80, Score:  206.00, Epsilon: 0.178
# Episode 1726, Reward:  -91.20, Score:  154.00, Epsilon: 0.178
# Episode 1727, Reward:  654.20, Score:  570.00, Epsilon: 0.178
# Episode 1728, Reward:  396.30, Score:  412.00, Epsilon: 0.177
# Episode 1729, Reward:  780.50, Score:  630.00, Epsilon: 0.177
# Episode 1730, Reward:  235.70, Score:  320.00, Epsilon: 0.177
# Episode 1731, Reward:  441.90, Score:  446.00, Epsilon: 0.177
# Episode 1732, Reward:  -46.00, Score:  154.00, Epsilon: 0.177
# Episode 1733, Reward:  562.00, Score:  478.00, Epsilon: 0.177
# Episode 1734, Reward:  165.90, Score:  292.00, Epsilon: 0.176
# Episode 1735, Reward:  205.80, Score:  290.00, Epsilon: 0.176
# Episode 1736, Reward:  464.50, Score:  430.00, Epsilon: 0.176
# Episode 1737, Reward:  300.20, Score:  324.00, Epsilon: 0.176
# Episode 1738, Reward:  201.40, Score:  304.00, Epsilon: 0.176
# Episode 1739, Reward:  353.30, Score:  378.00, Epsilon: 0.176
# Episode 1740, Reward:  327.20, Score:  348.00, Epsilon: 0.175
# Episode 1741, Reward:   13.40, Score:  212.00, Epsilon: 0.175
# Episode 1742, Reward:   54.40, Score:  196.00, Epsilon: 0.175
# Episode 1743, Reward:  164.20, Score:  294.00, Epsilon: 0.175
# Episode 1744, Reward:  116.40, Score:  248.00, Epsilon: 0.175
# Episode 1745, Reward:  707.10, Score:  556.00, Epsilon: 0.174
# Episode 1746, Reward:  810.50, Score:  650.00, Epsilon: 0.174
# Episode 1747, Reward:  269.20, Score:  308.00, Epsilon: 0.174
# Episode 1748, Reward:  287.40, Score:  350.00, Epsilon: 0.174
# Episode 1749, Reward:  -86.40, Score:  134.00, Epsilon: 0.174
# Episode 1750, Reward:  538.00, Score:  470.00, Epsilon: 0.174
# Checkpoint saved at episode 1750, best score: 2374.00
# Episode 1751, Reward:  197.50, Score:  276.00, Epsilon: 0.173
# Episode 1752, Reward:   12.80, Score:  202.00, Epsilon: 0.173
# Episode 1753, Reward:  157.70, Score:  302.00, Epsilon: 0.173
# Episode 1754, Reward:  219.20, Score:  294.00, Epsilon: 0.173
# Episode 1755, Reward:  685.00, Score:  566.00, Epsilon: 0.173
# Episode 1756, Reward:  208.90, Score:  312.00, Epsilon: 0.173
# Episode 1757, Reward:  199.60, Score:  302.00, Epsilon: 0.172
# Episode 1758, Reward:  102.10, Score:  226.00, Epsilon: 0.172
# Episode 1759, Reward:  130.70, Score:  264.00, Epsilon: 0.172
# Episode 1760, Reward:  172.90, Score:  272.00, Epsilon: 0.172
# Episode 1761, Reward: 1230.20, Score:  844.00, Epsilon: 0.172
# Episode 1762, Reward:  257.00, Score:  346.00, Epsilon: 0.172
# Episode 1763, Reward: 1130.20, Score:  804.00, Epsilon: 0.171
# Episode 1764, Reward:  206.80, Score:  322.00, Epsilon: 0.171
# Episode 1765, Reward:  194.30, Score:  304.00, Epsilon: 0.171
# Episode 1766, Reward:  201.90, Score:  310.00, Epsilon: 0.171
# Episode 1767, Reward:  320.10, Score:  362.00, Epsilon: 0.171
# Episode 1768, Reward:   56.70, Score:  196.00, Epsilon: 0.171
# Episode 1769, Reward:  505.50, Score:  438.00, Epsilon: 0.170
# Episode 1770, Reward:  107.30, Score:  250.00, Epsilon: 0.170
# Episode 1771, Reward:  -78.90, Score:  114.00, Epsilon: 0.170
# Episode 1772, Reward:  172.90, Score:  262.00, Epsilon: 0.170
# Episode 1773, Reward:  171.80, Score:  256.00, Epsilon: 0.170
# Episode 1774, Reward:  347.30, Score:  332.00, Epsilon: 0.170
# Episode 1775, Reward:  546.40, Score:  494.00, Epsilon: 0.169
# Episode 1776, Reward:  526.00, Score:  514.00, Epsilon: 0.169
# Episode 1777, Reward:  629.80, Score:  548.00, Epsilon: 0.169
# Episode 1778, Reward:  446.50, Score:  440.00, Epsilon: 0.169
# Episode 1779, Reward:  267.50, Score:  340.00, Epsilon: 0.169
# Episode 1780, Reward:  441.70, Score:  454.00, Epsilon: 0.168
# Episode 1781, Reward:  451.00, Score:  414.00, Epsilon: 0.168
# Episode 1782, Reward:   11.80, Score:  210.00, Epsilon: 0.168
# Episode 1783, Reward:  375.30, Score:  366.00, Epsilon: 0.168
# Episode 1784, Reward:  576.40, Score:  466.00, Epsilon: 0.168
# Episode 1785, Reward:  302.00, Score:  346.00, Epsilon: 0.168
# Episode 1786, Reward:  104.80, Score:  240.00, Epsilon: 0.167
# Episode 1787, Reward:   67.30, Score:  228.00, Epsilon: 0.167
# Episode 1788, Reward:  557.10, Score:  508.00, Epsilon: 0.167
# Episode 1789, Reward:  136.90, Score:  272.00, Epsilon: 0.167
# Episode 1790, Reward:  136.10, Score:  210.00, Epsilon: 0.167
# Episode 1791, Reward:  251.40, Score:  334.00, Epsilon: 0.167
# Episode 1792, Reward:  181.50, Score:  264.00, Epsilon: 0.166
# Episode 1793, Reward:  403.40, Score:  402.00, Epsilon: 0.166
# Episode 1794, Reward:  598.20, Score:  524.00, Epsilon: 0.166
# Episode 1795, Reward:  162.20, Score:  262.00, Epsilon: 0.166
# Episode 1796, Reward:  237.20, Score:  322.00, Epsilon: 0.166
# Episode 1797, Reward:  251.20, Score:  334.00, Epsilon: 0.166
# Episode 1798, Reward:  299.90, Score:  346.00, Epsilon: 0.165
# Episode 1799, Reward:  -60.50, Score:  134.00, Epsilon: 0.165
# Episode 1800, Reward:  -49.30, Score:  162.00, Epsilon: 0.165
# Checkpoint saved at episode 1800, best score: 2374.00
# Episode 1801, Reward:  254.80, Score:  312.00, Epsilon: 0.165
# Episode 1802, Reward:  573.00, Score:  496.00, Epsilon: 0.165
# Episode 1803, Reward:  323.90, Score:  358.00, Epsilon: 0.165
# Episode 1804, Reward: 1738.80, Score: 1182.00, Epsilon: 0.164
# Episode 1805, Reward:  650.90, Score:  574.00, Epsilon: 0.164
# Episode 1806, Reward:  706.80, Score:  548.00, Epsilon: 0.164
# Episode 1807, Reward:   64.80, Score:  232.00, Epsilon: 0.164
# Episode 1808, Reward:  339.90, Score:  394.00, Epsilon: 0.164
# Episode 1809, Reward:   20.20, Score:  184.00, Epsilon: 0.164
# Episode 1810, Reward:  519.90, Score:  464.00, Epsilon: 0.164
# Episode 1811, Reward: 1725.70, Score: 1178.00, Epsilon: 0.163
# Episode 1812, Reward:  521.40, Score:  486.00, Epsilon: 0.163
# Episode 1813, Reward:  128.00, Score:  238.00, Epsilon: 0.163
# Episode 1814, Reward:  -15.90, Score:  176.00, Epsilon: 0.163
# Episode 1815, Reward:  699.60, Score:  582.00, Epsilon: 0.163
# Episode 1816, Reward:  537.80, Score:  522.00, Epsilon: 0.163
# Episode 1817, Reward:  288.20, Score:  354.00, Epsilon: 0.162
# Episode 1818, Reward:  497.00, Score:  472.00, Epsilon: 0.162
# Episode 1819, Reward:  857.20, Score:  648.00, Epsilon: 0.162
# Episode 1820, Reward:  372.30, Score:  392.00, Epsilon: 0.162
# Episode 1821, Reward:  730.60, Score:  632.00, Epsilon: 0.162
# Episode 1822, Reward:  710.30, Score:  564.00, Epsilon: 0.162
# Episode 1823, Reward:  134.70, Score:  246.00, Epsilon: 0.161
# Episode 1824, Reward:  -32.70, Score:  170.00, Epsilon: 0.161
# Episode 1825, Reward:  689.10, Score:  612.00, Epsilon: 0.161
# Episode 1826, Reward: 1039.20, Score:  774.00, Epsilon: 0.161
# Episode 1827, Reward:  303.40, Score:  348.00, Epsilon: 0.161
# Episode 1828, Reward:  922.40, Score:  738.00, Epsilon: 0.161
# Episode 1829, Reward:  229.30, Score:  334.00, Epsilon: 0.160
# Episode 1830, Reward:  152.50, Score:  280.00, Epsilon: 0.160
# Episode 1831, Reward:    2.20, Score:  162.00, Epsilon: 0.160
# Episode 1832, Reward:  126.40, Score:  268.00, Epsilon: 0.160
# Episode 1833, Reward:  465.50, Score:  434.00, Epsilon: 0.160
# Episode 1834, Reward:  114.60, Score:  252.00, Epsilon: 0.160
# Episode 1835, Reward:  102.10, Score:  240.00, Epsilon: 0.159
# Episode 1836, Reward:  870.70, Score:  686.00, Epsilon: 0.159
# Episode 1837, Reward:  398.30, Score:  432.00, Epsilon: 0.159
# Episode 1838, Reward:  167.80, Score:  254.00, Epsilon: 0.159
# Episode 1839, Reward:   23.00, Score:  170.00, Epsilon: 0.159
# Episode 1840, Reward:  432.10, Score:  438.00, Epsilon: 0.159
# Episode 1841, Reward:   60.90, Score:  196.00, Epsilon: 0.159
# Episode 1842, Reward:   35.30, Score:  224.00, Epsilon: 0.158
# Episode 1843, Reward:  614.90, Score:  518.00, Epsilon: 0.158
# Episode 1844, Reward:  147.30, Score:  270.00, Epsilon: 0.158
# Episode 1845, Reward:  151.10, Score:  264.00, Epsilon: 0.158
# Episode 1846, Reward:  512.40, Score:  446.00, Epsilon: 0.158
# Episode 1847, Reward:  220.60, Score:  280.00, Epsilon: 0.158
# Episode 1848, Reward:  459.00, Score:  460.00, Epsilon: 0.157
# Episode 1849, Reward:  590.50, Score:  516.00, Epsilon: 0.157
# Episode 1850, Reward: 1177.50, Score:  872.00, Epsilon: 0.157
# Checkpoint saved at episode 1850, best score: 2374.00
# Episode 1851, Reward:  -53.80, Score:  134.00, Epsilon: 0.157
# Episode 1852, Reward:   -1.70, Score:  180.00, Epsilon: 0.157
# Episode 1853, Reward:  441.60, Score:  412.00, Epsilon: 0.157
# Episode 1854, Reward:   28.20, Score:  212.00, Epsilon: 0.156
# Episode 1855, Reward:  -77.40, Score:  144.00, Epsilon: 0.156
# Episode 1856, Reward:  187.70, Score:  296.00, Epsilon: 0.156
# Episode 1857, Reward:  -51.70, Score:  158.00, Epsilon: 0.156
# Episode 1858, Reward:  384.70, Score:  402.00, Epsilon: 0.156
# Episode 1859, Reward:  103.10, Score:  236.00, Epsilon: 0.156
# Episode 1860, Reward:  358.30, Score:  402.00, Epsilon: 0.156
# Episode 1861, Reward:   77.30, Score:  228.00, Epsilon: 0.155
# Episode 1862, Reward:  308.10, Score:  346.00, Epsilon: 0.155
# Episode 1863, Reward:  284.30, Score:  346.00, Epsilon: 0.155
# Episode 1864, Reward:  497.90, Score:  438.00, Epsilon: 0.155
# Episode 1865, Reward:  254.60, Score:  318.00, Epsilon: 0.155
# Episode 1866, Reward:   43.40, Score:  206.00, Epsilon: 0.155
# Episode 1867, Reward:  327.80, Score:  356.00, Epsilon: 0.154
# Episode 1868, Reward:  147.20, Score:  268.00, Epsilon: 0.154
# Episode 1869, Reward: 1096.00, Score:  816.00, Epsilon: 0.154
# Episode 1870, Reward:  294.20, Score:  332.00, Epsilon: 0.154
# Episode 1871, Reward:   18.10, Score:  178.00, Epsilon: 0.154
# Episode 1872, Reward:   68.80, Score:  220.00, Epsilon: 0.154
# Episode 1873, Reward:  379.60, Score:  396.00, Epsilon: 0.154
# Episode 1874, Reward:  634.10, Score:  562.00, Epsilon: 0.153
# Episode 1875, Reward:   64.80, Score:  206.00, Epsilon: 0.153
# Episode 1876, Reward:  517.00, Score:  474.00, Epsilon: 0.153
# Episode 1877, Reward:   18.30, Score:  178.00, Epsilon: 0.153
# Episode 1878, Reward:  477.00, Score:  496.00, Epsilon: 0.153
# Episode 1879, Reward:  496.20, Score:  458.00, Epsilon: 0.153
# Episode 1880, Reward:  407.60, Score:  422.00, Epsilon: 0.152
# Episode 1881, Reward:  130.20, Score:  284.00, Epsilon: 0.152
# Episode 1882, Reward:  275.50, Score:  362.00, Epsilon: 0.152
# Episode 1883, Reward:  354.40, Score:  370.00, Epsilon: 0.152
# Episode 1884, Reward:  215.00, Score:  328.00, Epsilon: 0.152
# Episode 1885, Reward:   11.80, Score:  188.00, Epsilon: 0.152
# Episode 1886, Reward:   58.50, Score:  242.00, Epsilon: 0.152
# Episode 1887, Reward:  995.40, Score:  714.00, Epsilon: 0.151
# Episode 1888, Reward:  421.10, Score:  416.00, Epsilon: 0.151
# Episode 1889, Reward:  176.80, Score:  278.00, Epsilon: 0.151
# Episode 1890, Reward:  738.80, Score:  592.00, Epsilon: 0.151
# Episode 1891, Reward:  302.90, Score:  348.00, Epsilon: 0.151
# Episode 1892, Reward:  109.90, Score:  238.00, Epsilon: 0.151
# Episode 1893, Reward:  334.10, Score:  368.00, Epsilon: 0.150
# Episode 1894, Reward:  284.40, Score:  318.00, Epsilon: 0.150
# Episode 1895, Reward:  168.20, Score:  290.00, Epsilon: 0.150
# Episode 1896, Reward:  574.00, Score:  510.00, Epsilon: 0.150
# Episode 1897, Reward:  274.90, Score:  336.00, Epsilon: 0.150
# Episode 1898, Reward:  266.40, Score:  352.00, Epsilon: 0.150
# Episode 1899, Reward:  590.00, Score:  532.00, Epsilon: 0.150
# Episode 1900, Reward:  368.30, Score:  358.00, Epsilon: 0.149
# Checkpoint saved at episode 1900, best score: 2374.00
# Episode 1901, Reward:  266.00, Score:  340.00, Epsilon: 0.149
# Episode 1902, Reward:  476.90, Score:  490.00, Epsilon: 0.149
# Episode 1903, Reward:  573.20, Score:  518.00, Epsilon: 0.149
# Episode 1904, Reward:  333.60, Score:  382.00, Epsilon: 0.149
# Episode 1905, Reward:  205.00, Score:  302.00, Epsilon: 0.149
# Episode 1906, Reward:  568.60, Score:  512.00, Epsilon: 0.149
# Episode 1907, Reward:   90.90, Score:  208.00, Epsilon: 0.148
# Episode 1908, Reward:  831.00, Score:  666.00, Epsilon: 0.148
# Episode 1909, Reward:   56.30, Score:  218.00, Epsilon: 0.148
# Episode 1910, Reward:  267.30, Score:  346.00, Epsilon: 0.148
# Episode 1911, Reward: -165.50, Score:   60.00, Epsilon: 0.148
# Episode 1912, Reward:  119.20, Score:  234.00, Epsilon: 0.148
# Episode 1913, Reward:  380.40, Score:  348.00, Epsilon: 0.147
# Episode 1914, Reward:  635.40, Score:  558.00, Epsilon: 0.147
# Episode 1915, Reward:   -8.00, Score:  144.00, Epsilon: 0.147
# Episode 1916, Reward:   41.50, Score:  200.00, Epsilon: 0.147
# Episode 1917, Reward:   39.60, Score:  210.00, Epsilon: 0.147
# Episode 1918, Reward:  234.10, Score:  312.00, Epsilon: 0.147
# Episode 1919, Reward:  668.30, Score:  542.00, Epsilon: 0.147
# Episode 1920, Reward:  209.30, Score:  304.00, Epsilon: 0.146
# Episode 1921, Reward:  -44.00, Score:  176.00, Epsilon: 0.146
# Episode 1922, Reward:  231.80, Score:  324.00, Epsilon: 0.146
# Episode 1923, Reward:  530.80, Score:  498.00, Epsilon: 0.146
# Episode 1924, Reward:  825.40, Score:  674.00, Epsilon: 0.146
# Episode 1925, Reward:  389.80, Score:  364.00, Epsilon: 0.146
# Episode 1926, Reward:  483.90, Score:  430.00, Epsilon: 0.146
# Episode 1927, Reward: -118.50, Score:  134.00, Epsilon: 0.145
# Episode 1928, Reward:  101.10, Score:  246.00, Epsilon: 0.145
# Episode 1929, Reward:  280.00, Score:  344.00, Epsilon: 0.145
# Episode 1930, Reward:  424.60, Score:  434.00, Epsilon: 0.145
# Episode 1931, Reward:  266.70, Score:  290.00, Epsilon: 0.145
# Episode 1932, Reward:  905.70, Score:  698.00, Epsilon: 0.145
# Episode 1933, Reward:  -20.90, Score:  180.00, Epsilon: 0.145
# Episode 1934, Reward: 1267.30, Score:  880.00, Epsilon: 0.144
# Episode 1935, Reward: 1328.20, Score:  948.00, Epsilon: 0.144
# Episode 1936, Reward:  324.40, Score:  364.00, Epsilon: 0.144
# Episode 1937, Reward:  240.40, Score:  338.00, Epsilon: 0.144
# Episode 1938, Reward:  135.70, Score:  280.00, Epsilon: 0.144
# Episode 1939, Reward:  368.00, Score:  356.00, Epsilon: 0.144
# Episode 1940, Reward:  273.00, Score:  344.00, Epsilon: 0.144
# Episode 1941, Reward:  782.90, Score:  640.00, Epsilon: 0.143
# Episode 1942, Reward:  531.70, Score:  482.00, Epsilon: 0.143
# Episode 1943, Reward:  284.20, Score:  330.00, Epsilon: 0.143
# Episode 1944, Reward:  674.20, Score:  596.00, Epsilon: 0.143
# ...
# Episode 1965, Reward:  310.30, Score:  370.00, Epsilon: 0.140
# Episode 1966, Reward: -103.00, Score:  120.00, Epsilon: 0.140
# Episode 1967, Reward:  129.70, Score:  206.00, Epsilon: 0.140
# Episode 1968, Reward:   83.00, Score:  212.00, Epsilon: 0.140
# Episode 1969, Reward:   43.40, Score:  218.00, Epsilon: 0.139
# Episode 1970, Reward: -164.90, Score:  100.00, Epsilon: 0.139
# Episode 1971, Reward:  748.00, Score:  600.00, Epsilon: 0.139
# Episode 1972, Reward:  172.00, Score:  278.00, Epsilon: 0.139
# Episode 1973, Reward:   -4.50, Score:  182.00, Epsilon: 0.139
# Episode 1974, Reward:  -65.60, Score:  144.00, Epsilon: 0.139
# Episode 1975, Reward:  410.20, Score:  398.00, Epsilon: 0.139
# Episode 1976, Reward:  456.60, Score:  456.00, Epsilon: 0.138
# Episode 1977, Reward: -119.20, Score:  116.00, Epsilon: 0.138
# Episode 1978, Reward:   70.60, Score:  216.00, Epsilon: 0.138
# Episode 1979, Reward:  160.40, Score:  274.00, Epsilon: 0.138
# Episode 1980, Reward:    4.10, Score:  190.00, Epsilon: 0.138
# Episode 1981, Reward:   48.40, Score:  200.00, Epsilon: 0.138
# Episode 1982, Reward:  438.80, Score:  392.00, Epsilon: 0.138
# Episode 1983, Reward:  190.10, Score:  292.00, Epsilon: 0.138
# Episode 1984, Reward:   -2.00, Score:  182.00, Epsilon: 0.137
# Episode 1985, Reward: -188.90, Score:   86.00, Epsilon: 0.137
# Episode 1986, Reward:  823.40, Score:  660.00, Epsilon: 0.137
# Episode 1987, Reward:  231.20, Score:  304.00, Epsilon: 0.137
# Episode 1988, Reward:  570.60, Score:  536.00, Epsilon: 0.137
# Episode 1989, Reward:  548.20, Score:  490.00, Epsilon: 0.137
# Episode 1990, Reward:  756.60, Score:  634.00, Epsilon: 0.137
# Episode 1991, Reward:  229.20, Score:  260.00, Epsilon: 0.136
# Episode 1992, Reward:  282.90, Score:  318.00, Epsilon: 0.136
# Episode 1993, Reward:  349.00, Score:  388.00, Epsilon: 0.136
# Episode 1994, Reward:  305.00, Score:  366.00, Epsilon: 0.136
# Episode 1995, Reward:   63.60, Score:  214.00, Epsilon: 0.136
# Episode 1996, Reward:  -77.30, Score:  160.00, Epsilon: 0.136
# Episode 1997, Reward:  578.10, Score:  450.00, Epsilon: 0.136
# Episode 1998, Reward: 1372.50, Score:  982.00, Epsilon: 0.135
# Episode 1999, Reward:   83.10, Score:  212.00, Epsilon: 0.135
# Episode 2000, Reward:  310.40, Score:  332.00, Epsilon: 0.135
# Checkpoint saved at episode 2000, best score: 2374.00
# Episode 2001, Reward:  264.80, Score:  328.00, Epsilon: 0.135
# Episode 2002, Reward:   30.80, Score:  214.00, Epsilon: 0.135
# Episode 2003, Reward:  990.80, Score:  730.00, Epsilon: 0.135
# Episode 2004, Reward:    1.00, Score:  192.00, Epsilon: 0.135
# Episode 2005, Reward:  281.40, Score:  338.00, Epsilon: 0.135
# Episode 2006, Reward:  319.40, Score:  402.00, Epsilon: 0.134
# Episode 2007, Reward:  506.20, Score:  488.00, Epsilon: 0.134
# Episode 2008, Reward:  476.60, Score:  424.00, Epsilon: 0.134
# Episode 2009, Reward:   13.20, Score:  162.00, Epsilon: 0.134
# Episode 2010, Reward:  415.90, Score:  400.00, Epsilon: 0.134
# Episode 2011, Reward:  374.40, Score:  418.00, Epsilon: 0.134
# Episode 2012, Reward:  151.90, Score:  262.00, Epsilon: 0.134
# Episode 2013, Reward:  449.70, Score:  434.00, Epsilon: 0.133
# Episode 2014, Reward: -175.00, Score:   66.00, Epsilon: 0.133
# Episode 2015, Reward:  386.50, Score:  408.00, Epsilon: 0.133
# Episode 2016, Reward:  128.20, Score:  228.00, Epsilon: 0.133
# Episode 2017, Reward: -186.00, Score:   74.00, Epsilon: 0.133
# Episode 2018, Reward:  295.50, Score:  350.00, Epsilon: 0.133
# Episode 2019, Reward:  463.00, Score:  414.00, Epsilon: 0.133
# Episode 2020, Reward:  174.10, Score:  300.00, Epsilon: 0.133
# Episode 2021, Reward:  145.70, Score:  270.00, Epsilon: 0.132
# Episode 2022, Reward:  170.50, Score:  274.00, Epsilon: 0.132
# Episode 2023, Reward:  173.00, Score:  296.00, Epsilon: 0.132
# Episode 2024, Reward:  275.00, Score:  302.00, Epsilon: 0.132
# Episode 2025, Reward:  134.90, Score:  262.00, Epsilon: 0.132
# Episode 2026, Reward:  739.70, Score:  618.00, Epsilon: 0.132
# Episode 2027, Reward:  232.60, Score:  290.00, Epsilon: 0.132
# Episode 2028, Reward: -121.80, Score:  118.00, Epsilon: 0.131
# Episode 2029, Reward:   45.10, Score:  218.00, Epsilon: 0.131
# Episode 2030, Reward:  251.60, Score:  296.00, Epsilon: 0.131
# Episode 2031, Reward:   83.10, Score:  226.00, Epsilon: 0.131
# Episode 2032, Reward:  528.80, Score:  484.00, Epsilon: 0.131
# Episode 2033, Reward:  943.80, Score:  750.00, Epsilon: 0.131
# Episode 2034, Reward:  269.70, Score:  352.00, Epsilon: 0.131
# Episode 2035, Reward:  341.40, Score:  378.00, Epsilon: 0.131
# Episode 2036, Reward:  127.70, Score:  246.00, Epsilon: 0.130
# Episode 2037, Reward:   43.30, Score:  192.00, Epsilon: 0.130
# Episode 2038, Reward:  322.30, Score:  372.00, Epsilon: 0.130
# Episode 2039, Reward:    1.40, Score:  200.00, Epsilon: 0.130
# Episode 2040, Reward:  850.90, Score:  634.00, Epsilon: 0.130
# Episode 2041, Reward:  816.10, Score:  620.00, Epsilon: 0.130
# Episode 2042, Reward:  248.60, Score:  320.00, Epsilon: 0.130
# Episode 2043, Reward:  -56.60, Score:  152.00, Epsilon: 0.130
# Episode 2044, Reward:  523.00, Score:  448.00, Epsilon: 0.129
# Episode 2045, Reward:  383.40, Score:  418.00, Epsilon: 0.129
# Episode 2046, Reward:  166.90, Score:  294.00, Epsilon: 0.129
# Episode 2047, Reward:    0.60, Score:  180.00, Epsilon: 0.129
# Episode 2048, Reward:  335.00, Score:  372.00, Epsilon: 0.129
# Episode 2049, Reward:  198.20, Score:  264.00, Epsilon: 0.129
# Episode 2050, Reward:  215.90, Score:  312.00, Epsilon: 0.129
# Checkpoint saved at episode 2050, best score: 2374.00
# Episode 2051, Reward:  202.90, Score:  302.00, Epsilon: 0.128
# Episode 2052, Reward:   65.20, Score:  192.00, Epsilon: 0.128
# Episode 2053, Reward:   71.50, Score:  212.00, Epsilon: 0.128
# Episode 2054, Reward:  580.30, Score:  516.00, Epsilon: 0.128
# Episode 2055, Reward:   76.50, Score:  194.00, Epsilon: 0.128
# Episode 2056, Reward:  -33.80, Score:  154.00, Epsilon: 0.128
# Episode 2057, Reward:  204.60, Score:  296.00, Epsilon: 0.128
# Episode 2058, Reward:  176.30, Score:  292.00, Epsilon: 0.128
# Episode 2059, Reward:  406.30, Score:  430.00, Epsilon: 0.127
# Episode 2060, Reward:  451.60, Score:  386.00, Epsilon: 0.127
# Episode 2061, Reward:  -63.50, Score:  144.00, Epsilon: 0.127
# Episode 2062, Reward:  281.70, Score:  308.00, Epsilon: 0.127
# Episode 2063, Reward:  410.10, Score:  408.00, Epsilon: 0.127
# Episode 2064, Reward:   87.90, Score:  222.00, Epsilon: 0.127
# Episode 2065, Reward:   27.10, Score:  216.00, Epsilon: 0.127
# Episode 2066, Reward:   40.10, Score:  194.00, Epsilon: 0.127
# Episode 2067, Reward:  264.50, Score:  298.00, Epsilon: 0.126
# Episode 2068, Reward:  619.70, Score:  530.00, Epsilon: 0.126
# Episode 2069, Reward:   52.10, Score:  222.00, Epsilon: 0.126
# Episode 2070, Reward:  -54.60, Score:  152.00, Epsilon: 0.126
# Episode 2071, Reward:  -64.90, Score:  134.00, Epsilon: 0.126
# Episode 2072, Reward:  177.30, Score:  292.00, Epsilon: 0.126
# Episode 2073, Reward:   23.20, Score:  192.00, Epsilon: 0.126
# Episode 2074, Reward:  138.60, Score:  262.00, Epsilon: 0.126
# Episode 2075, Reward:  219.20, Score:  316.00, Epsilon: 0.125
# Episode 2076, Reward: -147.30, Score:  110.00, Epsilon: 0.125
# Episode 2077, Reward:  315.00, Score:  356.00, Epsilon: 0.125
# Episode 2078, Reward:   17.00, Score:  200.00, Epsilon: 0.125
# Episode 2079, Reward:   61.90, Score:  218.00, Epsilon: 0.125
# Episode 2080, Reward:    0.20, Score:  170.00, Epsilon: 0.125
# Episode 2081, Reward:   84.00, Score:  204.00, Epsilon: 0.125
# Episode 2082, Reward:  182.60, Score:  286.00, Epsilon: 0.125
# Episode 2083, Reward:   11.20, Score:  196.00, Epsilon: 0.124
# Episode 2084, Reward:  157.40, Score:  280.00, Epsilon: 0.124
# Episode 2085, Reward:  288.60, Score:  346.00, Epsilon: 0.124
# Episode 2086, Reward:  280.00, Score:  350.00, Epsilon: 0.124
# Episode 2087, Reward: -119.90, Score:  118.00, Epsilon: 0.124
# Episode 2088, Reward:  538.90, Score:  470.00, Epsilon: 0.124
# Episode 2089, Reward:  -47.20, Score:  154.00, Epsilon: 0.124
# Episode 2090, Reward:   -7.80, Score:  164.00, Epsilon: 0.124
# Episode 2091, Reward:  317.20, Score:  382.00, Epsilon: 0.123
# Episode 2092, Reward:  519.40, Score:  458.00, Epsilon: 0.123
# Episode 2093, Reward:  443.60, Score:  436.00, Epsilon: 0.123
# Episode 2094, Reward:  142.50, Score:  240.00, Epsilon: 0.123
# Episode 2095, Reward:   46.80, Score:  196.00, Epsilon: 0.123
# Episode 2096, Reward:  212.50, Score:  304.00, Epsilon: 0.123
# Episode 2097, Reward:  357.90, Score:  378.00, Epsilon: 0.123
# Episode 2098, Reward:   18.40, Score:  208.00, Epsilon: 0.123
# Episode 2099, Reward:  491.30, Score:  494.00, Epsilon: 0.122
# Episode 2100, Reward: 1885.00, Score: 1270.00, Epsilon: 0.122
# Checkpoint saved at episode 2100, best score: 2374.00
# Episode 2101, Reward:    1.90, Score:  184.00, Epsilon: 0.122
# Episode 2102, Reward:  315.50, Score:  356.00, Epsilon: 0.122
# Episode 2103, Reward:   34.50, Score:  210.00, Epsilon: 0.122
# Episode 2104, Reward:  -36.80, Score:  154.00, Epsilon: 0.122
# Episode 2105, Reward:  193.10, Score:  254.00, Epsilon: 0.122
# Episode 2106, Reward:  673.30, Score:  536.00, Epsilon: 0.122
# Episode 2107, Reward:  171.10, Score:  302.00, Epsilon: 0.121
# Episode 2108, Reward:   39.50, Score:  214.00, Epsilon: 0.121
# Episode 2109, Reward:  261.00, Score:  308.00, Epsilon: 0.121
# Episode 2110, Reward:  580.80, Score:  490.00, Epsilon: 0.121
# Episode 2111, Reward:  133.50, Score:  260.00, Epsilon: 0.121
# Episode 2112, Reward:  320.30, Score:  362.00, Epsilon: 0.121
# Episode 2113, Reward: -114.60, Score:  120.00, Epsilon: 0.121
# Episode 2114, Reward:  592.50, Score:  516.00, Epsilon: 0.121
# Episode 2115, Reward:  120.30, Score:  294.00, Epsilon: 0.121
# Episode 2116, Reward:  291.90, Score:  360.00, Epsilon: 0.120
# Episode 2117, Reward:   51.40, Score:  214.00, Epsilon: 0.120
# Episode 2118, Reward:   77.40, Score:  222.00, Epsilon: 0.120
# Episode 2119, Reward:  130.80, Score:  260.00, Epsilon: 0.120
# Episode 2120, Reward:  635.80, Score:  558.00, Epsilon: 0.120
# Episode 2121, Reward:  158.80, Score:  276.00, Epsilon: 0.120
# Episode 2122, Reward:  278.00, Score:  332.00, Epsilon: 0.120
# Episode 2123, Reward:   11.50, Score:  184.00, Epsilon: 0.120
# Episode 2124, Reward:   63.80, Score:  236.00, Epsilon: 0.119
# Episode 2125, Reward:  299.80, Score:  320.00, Epsilon: 0.119
# Episode 2126, Reward:   98.40, Score:  246.00, Epsilon: 0.119
# Episode 2127, Reward:   67.00, Score:  234.00, Epsilon: 0.119
# Episode 2128, Reward:  676.10, Score:  566.00, Epsilon: 0.119
# Episode 2129, Reward:   96.80, Score:  228.00, Epsilon: 0.119
# Episode 2130, Reward:  126.20, Score:  248.00, Epsilon: 0.119
# Episode 2131, Reward:  679.60, Score:  496.00, Epsilon: 0.119
# Episode 2132, Reward:  456.20, Score:  446.00, Epsilon: 0.118
# Episode 2133, Reward:  -47.00, Score:  162.00, Epsilon: 0.118
# Episode 2134, Reward:  610.00, Score:  508.00, Epsilon: 0.118
# Episode 2135, Reward: -152.60, Score:  100.00, Epsilon: 0.118
# Episode 2136, Reward:  235.40, Score:  322.00, Epsilon: 0.118
# Episode 2137, Reward: -165.60, Score:   72.00, Epsilon: 0.118
# Episode 2138, Reward: -171.20, Score:   94.00, Epsilon: 0.118
# Episode 2139, Reward:   60.60, Score:  212.00, Epsilon: 0.118
# Episode 2140, Reward:  533.60, Score:  500.00, Epsilon: 0.118
# Episode 2141, Reward:   80.70, Score:  212.00, Epsilon: 0.117
# Episode 2142, Reward:  854.70, Score:  672.00, Epsilon: 0.117
# Episode 2143, Reward:  540.40, Score:  524.00, Epsilon: 0.117
# Episode 2144, Reward:  430.70, Score:  420.00, Epsilon: 0.117
# Episode 2145, Reward:   90.70, Score:  234.00, Epsilon: 0.117
# Episode 2146, Reward:   73.90, Score:  238.00, Epsilon: 0.117
# Episode 2147, Reward:  -80.70, Score:  126.00, Epsilon: 0.117
# Episode 2148, Reward:  487.80, Score:  436.00, Epsilon: 0.117
# Episode 2149, Reward:  -89.20, Score:  138.00, Epsilon: 0.116
# Episode 2150, Reward:   16.10, Score:  196.00, Epsilon: 0.116
# Checkpoint saved at episode 2150, best score: 2374.00
# Episode 2151, Reward:   38.90, Score:  186.00, Epsilon: 0.116
# Episode 2152, Reward: -105.10, Score:  118.00, Epsilon: 0.116
# Episode 2153, Reward:  -38.20, Score:  162.00, Epsilon: 0.116
# Episode 2154, Reward: -147.50, Score:  102.00, Epsilon: 0.116
# Episode 2155, Reward:  410.80, Score:  410.00, Epsilon: 0.116
# Episode 2156, Reward:   36.40, Score:  214.00, Epsilon: 0.116
# Episode 2157, Reward:  282.80, Score:  358.00, Epsilon: 0.116
# Episode 2158, Reward:   72.50, Score:  244.00, Epsilon: 0.115
# Episode 2159, Reward:   35.20, Score:  196.00, Epsilon: 0.115
# Episode 2160, Reward:   73.00, Score:  220.00, Epsilon: 0.115
# Episode 2161, Reward:  314.30, Score:  372.00, Epsilon: 0.115
# Episode 2162, Reward:  344.70, Score:  348.00, Epsilon: 0.115
# Episode 2163, Reward:  112.80, Score:  236.00, Epsilon: 0.115
# Episode 2164, Reward:  425.20, Score:  398.00, Epsilon: 0.115
# Episode 2165, Reward:  150.00, Score:  266.00, Epsilon: 0.115
# Episode 2166, Reward:  537.10, Score:  472.00, Epsilon: 0.115
# Episode 2167, Reward:   79.60, Score:  216.00, Epsilon: 0.114
# Episode 2168, Reward:  132.10, Score:  222.00, Epsilon: 0.114
# Episode 2169, Reward:  294.10, Score:  332.00, Epsilon: 0.114
# Episode 2170, Reward:  -95.90, Score:  134.00, Epsilon: 0.114
# Episode 2171, Reward: -132.00, Score:   96.00, Epsilon: 0.114
# Episode 2172, Reward:  981.40, Score:  696.00, Epsilon: 0.114
# Episode 2173, Reward:  634.50, Score:  590.00, Epsilon: 0.114
# Episode 2174, Reward:  566.30, Score:  534.00, Epsilon: 0.114
# Episode 2175, Reward:  128.50, Score:  236.00, Epsilon: 0.113
# Episode 2176, Reward:  121.20, Score:  246.00, Epsilon: 0.113
# Episode 2177, Reward:  460.60, Score:  470.00, Epsilon: 0.113
# Episode 2178, Reward:   -2.10, Score:  194.00, Epsilon: 0.113
# Episode 2179, Reward:  595.30, Score:  522.00, Epsilon: 0.113
# Episode 2180, Reward:  270.40, Score:  338.00, Epsilon: 0.113
# Episode 2181, Reward:  -60.40, Score:  134.00, Epsilon: 0.113
# Episode 2182, Reward:  237.60, Score:  336.00, Epsilon: 0.113
# Episode 2183, Reward:  171.20, Score:  276.00, Epsilon: 0.113
# Episode 2184, Reward:   42.10, Score:  202.00, Epsilon: 0.112
# Episode 2185, Reward:  282.90, Score:  344.00, Epsilon: 0.112
# Episode 2186, Reward:  -30.70, Score:  166.00, Epsilon: 0.112
# Episode 2187, Reward:  -46.10, Score:  158.00, Epsilon: 0.112
# Episode 2188, Reward:  159.40, Score:  270.00, Epsilon: 0.112
# Episode 2189, Reward: -157.70, Score:   94.00, Epsilon: 0.112
# Episode 2190, Reward:   33.10, Score:  190.00, Epsilon: 0.112
# Episode 2191, Reward:  -81.10, Score:  154.00, Epsilon: 0.112
# Episode 2192, Reward:   81.60, Score:  232.00, Epsilon: 0.112
# Episode 2193, Reward:  703.70, Score:  588.00, Epsilon: 0.111
# Episode 2194, Reward:   21.50, Score:  182.00, Epsilon: 0.111
# Episode 2195, Reward: 1098.10, Score:  814.00, Epsilon: 0.111
# Episode 2196, Reward:  -43.30, Score:  160.00, Epsilon: 0.111
# Episode 2197, Reward:  113.40, Score:  246.00, Epsilon: 0.111
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 67
#      64         action = q.argmax(dim=1).item()  # 取得最大 Q 值對應的動作
#      66 # 執行動作 / Perform action
# ---> 67 next_state_raw, reward, done, info = env.step(action)
#      69 next_state_b, next_state = preprocess_state(next_state_raw, cur_state, False)
#      70 # 存入經驗  (去掉 batch 維度)
#
# Cell In[25], line 22, in SpaceShipEnv.step(self, action)
#      19 self.game.update(action)
#      21 if self.screen is None:
# ---> 22     self.game.draw()
#      23 else:
#      24     self.game.draw(self.screen)
#
# File z:\RL\template_v2\template_v2\space_ship_game_RL\game.py:162, in Game.draw(self, screen)
#     160 self.player.draw(surface)
#     161 self.player.sprite.bullet_group.draw(surface)
# --> 162 self.draw_text(surface, str(self.score), 18, WIDTH/2, 10)
#     163 self.draw_health(surface, self.player.sprite.health, 5, 15)
#     165 # 更新 state
#
# File z:\RL\template_v2\template_v2\space_ship_game_RL\game.py:51, in Game.draw_text(self, surf, text, size, x, y)
#      50 def draw_text(self, surf, text, size, x, y):
# ---> 51     font = pygame.font.Font(font_name, size)
#      52     text_surface = font.render(text, True, WHITE)
#      53     text_rect = text_surface.get_rect()
#
# KeyboardInterrupt:

# %%
from scipy.ndimage import gaussian_filter1d

reward_smooth = gaussian_filter1d(reward_history, sigma=50)
score_smooth = gaussian_filter1d(score_history, sigma=50)

# 畫圖
# plt.figure(figsize=(10, 5))
plt.plot(reward_history, label='Total Reward', alpha=0.8)
plt.plot(score_history, label='Score', alpha=0.8)
plt.plot(reward_smooth, label='Smoothed Total Reward', linewidth=2)
plt.plot(score_smooth, label='Smoothed Score', linewidth=2)

plt.legend(loc='upper left')
plt.xlabel("Episode")
plt.ylabel("Value")
plt.title("Training Reward Over Episodes")
plt.grid(True)
plt.tight_layout()
# plt.savefig("dqn_training_curve.png")
