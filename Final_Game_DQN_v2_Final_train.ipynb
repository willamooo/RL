# %%
import pygame
import os
import sys

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.backends.cudnn as cudnn
cudnn.benchmark = True

import numpy as np
from PIL import Image
import random
import matplotlib.pyplot as plt
from matplotlib import animation
from collections import deque

# %%
print(torch.cuda.is_available())  # 應該為 True
print(torch.version.cuda)         # 應該列出 CUDA 版本
print(torch.backends.cudnn.version())  # cuDNN 版本
# Out:
# True
# 12.1
# 90100

# %%
script_dir = os.path.join(os.getcwd(), 'space_ship_game_RL')
if script_dir not in sys.path:
    sys.path.append(script_dir)

from setting import *
from game import Game

# %%
class SpaceShipEnv():
    def __init__(self):
        pygame.init()
        pygame.font.init()

        # 延後畫面初始化，等 render() 時才設置
        self.screen = None
        self.clock = pygame.time.Clock()
        self.fps = FPS

        self.game = Game()

        self.action_space = [0, 1, 2, 3]
        self.observation = self.game.state
        self.prev_score = 0
        self.prev_health = self.game.player.sprite.health

    def step(self, action):
        self.game.update(action)

        if self.screen is None:
            self.game.draw()
        else:
            self.game.draw(self.screen)
            self.clock.tick(self.fps)

        # define the state by your game logic
        state = self.game.state

        # define the reward by your game logic
        reward  = 0.0

        # reward += (self.game.score - self.prev_score) * 0.1
        reward += self.game.is_hit_rock * 5

        reward += self.game.is_power_shield * 10
        reward += self.game.is_power_gun * 3

        reward -= self.game.is_collided * 15

        if not self.game.running:
            reward -= 50 # 死亡懲罰

        reward += 0.01
        
        reward += (self.game.score - self.prev_score) * 0.1
        self.prev_score = self.game.score
        
        done = not self.game.running or self.game.score >= 10000

        info = {
            "score": self.game.score,
            "lives": self.game.player.sprite.lives,
            "health": self.game.player.sprite.health
        }

        return state, reward, done, info

    def reset(self):
        self.game = Game()

        return self.game.state

    def render(self):
        if self.screen is None:
            self.screen = pygame.display.set_mode((WIDTH, HEIGHT))
            pygame.display.set_caption("SpaceShip RL Environment")

    def close(self):
        pygame.quit()

# %%
# Hyperparameters
num_episodes = 5000
batch_size = 256
gamma = 0.99
lr = 1e-4
epsilon_start = 1.0
epsilon_end = 0.01
epsilon_decay = 0.9995
memory_capacity = 100000  # 100000
target_update_freq = 2000   # 1000

# %%
epsilon_list=[]
epsilon=epsilon_start
for i in range(num_episodes):
    epsilon = max(epsilon_end, epsilon * epsilon_decay)
    epsilon_list.append(epsilon)
plt.plot(epsilon_list)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# CNN-based DQN Model
class DQN(nn.Module):
    def __init__(self, in_channels, num_actions):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, 32, kernel_size=8, stride=4),  # (C,84,84)→(32,20,20)
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),           # →(64,9,9)
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),           # →(64,7,7)
            nn.ReLU(),
        )
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 7 * 7, 512),
            nn.ReLU(),
            nn.Linear(512, num_actions)
        )


    def forward(self, x):
        x = self.conv(x / 255.0) 
        return self.fc(x)

# %%
# Replay buffer
# 用於儲存代理人經驗（狀態、動作、獎勵等）的緩衝區，支援隨機抽樣以打破時間相關性，有助於穩定訓練。

class ReplayMemory:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
        # Use deque with a fixed capacity to automatically discard the oldest experience when full.
        # 使用 deque 並設定最大長度，當容量滿時會自動移除最舊的資料。

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))
        # Store a single transition (experience) in the buffer.
        # 儲存一筆經驗（狀態轉移）進緩衝區。

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        # Randomly sample a batch of transitions to break correlation between consecutive samples.
        # 隨機抽取一批經驗，打破樣本間的時間關聯性，提高訓練穩定性。

        # Unpack each element into separate tensors for network input
        # 將 batch 拆解成分別的 tensor 以供神經網路訓練
        states, actions, rewards, next_states, dones = zip(*batch)
        
        # Convert the sampled data into tensors and move them to the specified device (CPU or GPU)
        # 將抽樣資料轉成 tensor 並移至指定設備（CPU/GPU）

        # states = torch.tensor(np.stack(states), dtype=torch.float32, device=device)
        # actions = torch.tensor(actions, dtype=torch.int64, device=device)
        # rewards = torch.tensor(rewards, dtype=torch.float32, device=device)
        # next_states = torch.tensor(np.stack(next_states), dtype=torch.float32, device=device)
        # dones = torch.tensor(dones, dtype=torch.float32, device=device)
        # return states, actions, rewards, next_states, dones
        # 檢查 state shape
        
        # 先在 CPU 上創建 Tensor，然後 pin memory 
        states = torch.stack(states).pin_memory()
        actions = torch.tensor(actions, dtype=torch.int64).unsqueeze(1).pin_memory()
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(1).pin_memory()
        next_states = torch.stack(next_states).pin_memory()
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(1).pin_memory()
        
        return states, actions, rewards, next_states, dones
    
        # return (
        #     torch.stack(states),
        #     torch.tensor(actions, dtype=torch.int64, device=device).unsqueeze(1),  # Add dimension for actions
        #     torch.tensor(rewards, dtype=torch.float32, device=device).unsqueeze(1),  # Add dimension for rewards    
        #     torch.stack(next_states),
        #     torch.tensor(dones, dtype=torch.float32, device=device).unsqueeze(1)  # Add dimension for dones
        # )

    def __len__(self):
        return len(self.buffer)
        # Return the current size of the buffer.
        # 回傳緩衝區目前儲存的資料數量。

# %%
# Preprocess frames (grayscale and resize to 84x84)
# 預處理影格：轉為灰階並縮放為 84x84

import cv2
def preprocess_state(state, stacked_state=None, is_new=False):
    gray = cv2.cvtColor(state, cv2.COLOR_RGB2GRAY)
    gray = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA)
    gray = torch.tensor(gray, dtype=torch.uint8).unsqueeze(0)        # (1,84,84)
    if is_new or stacked_state is None:
        stacked_state = gray.repeat(4, 1, 1)                         # (4,84,84)
    else:
        stacked_state = torch.cat((gray, stacked_state[:-1]), dim=0)
    return stacked_state.float().unsqueeze(0), stacked_state         # (1,4,84,84)


def preprocess_frame(frame):
    # frame 是 numpy array (H, W, 3)，先轉為 PIL Image
    # Input is a color image (RGB), convert to PIL format for easier processing.
    # 輸入是彩色圖像（RGB），轉成 PIL Image 以方便處理。
    image = Image.fromarray(frame)

    # 轉灰階
    # Convert the image to grayscale to reduce input complexity.
    # 將影像轉為灰階，降低輸入維度與計算量。
    image = image.convert('L')

    # resize 成 84x84
    # Resize the image to a standard 84x84 shape, as per DQN convention.
    # 依照 DQN 的慣例將影像統一縮放至 84x84。
    image = image.resize((84, 84), Image.Resampling.BILINEAR)  # or NEAREST, or LANCZOS

    # 轉回 numpy 並正規化
    # Convert back to NumPy and normalize pixel values to [0, 1].
    # 轉回 NumPy 格式並將像素值標準化到 [0, 1]。
    frame = np.asarray(image, dtype=np.float32) / 255.0

    return frame


def stack_frames(stacked_frames, state, is_new_episode):
    # 預處理目前影格
    frame = preprocess_frame(state)

    if is_new_episode or stacked_frames is None:
        # If it's a new episode or no previous frames, initialize with 4 identical frames
        # 若是新的一集或是尚未初始化，則用目前影格複製 4 次形成初始堆疊
        stacked_frames = deque([frame]*4, maxlen=4)
    else:
        # 否則把新影格加入到堆疊中，自動捨棄最舊的
        stacked_frames.append(frame)

    # Stack the 4 frames along the first dimension: shape becomes (4, 84, 84)
    # 沿著第一維（channel）堆疊成 4 通道輸入：形狀變成 (4, 84, 84)
    stacked_state = np.stack(stacked_frames, axis=0)

    return stacked_state, stacked_frames

# %%
# 初始化 Breakout 環境 / Initialize the Breakout environment
import torch.amp

env = SpaceShipEnv()
num_actions = len(env.action_space)
state_dim = 4
# 建立策略網路與目標網路 / Create policy and target networks
policy_net = DQN(state_dim, num_actions).to(device)
target_net = DQN(state_dim, num_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())  # 初始時讓目標網路等於策略網路
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=lr)
memory = ReplayMemory(memory_capacity)
scaler = torch.amp.GradScaler() 

# 載入模型（若有）
if os.path.exists('checkpoint.pth'):
    checkpoint = torch.load('checkpoint.pth', map_location=device)
    policy_net.load_state_dict(checkpoint['policy_net'])
    target_net.load_state_dict(checkpoint['target_net'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    start_episode   = checkpoint['episode'] + 1
    frame_idx       = checkpoint['total_steps']
    best_score      = checkpoint['best_score']
    epsilon         = checkpoint['epsilon']
    reward_history  = checkpoint['reward_history']
    score_history   = checkpoint['score_history']
    print(f"Loaded checkpoint from episode {start_episode}, best score: {best_score:.2f}, epsilon={epsilon:.3f}")
else:
    start_episode = 0
    frame_idx    = 0
    best_score = float('-inf')
    epsilon = epsilon_start
    reward_history = []
    score_history = []


# 訓練迴圈 / Training loop
# 每次可以訓練個100步(根據自己的設備與時間調整)，然後下一次都再接續上次的訓練模型接續往下訓練
# You can train for 100 steps each time (adjust according to your own equipment and time), 
# and then continue training from the last training model next time.
for episode in range(start_episode, 4000): # last time = 3200
    cur_state_b, cur_state = preprocess_state(env.reset(), None, True)  # 回傳 4×84×84
    episode_reward = 0
    # state, stacked_frames = stack_frames(None, state, True)
    done = False

    while not done:
        # ε-greedy 策略：隨機選擇動作或從模型中選擇 / Epsilon-greedy action selection
        # if random.random() < epsilon:
        #     action = random.choice(env.action_space)
        # else:
        #     with torch.no_grad():
        #         state_tensor = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
        #         action = policy_net(state_tensor).argmax(dim=1).item()

        frame_idx += 1
        if random.random() < epsilon:
            action = random.randrange(num_actions)
        else:
            with torch.no_grad():
                q = policy_net(cur_state_b.to(device))
                action = q.argmax(dim=1).item()  # 取得最大 Q 值對應的動作

        # 執行動作 / Perform action
        next_state_raw, reward, done, info = env.step(action)

        next_state_b, next_state = preprocess_state(next_state_raw, cur_state, False)
        # 存入經驗  (去掉 batch 維度)
        memory.push(cur_state.cpu(), action, reward, next_state.cpu(), done)
        cur_state_b, cur_state = next_state_b, next_state
        episode_reward += reward

        # 訓練模型 / Train the model from memory
        if len(memory) >= batch_size:
            for _ in range(4): # 你可以調整這個數字，例如 2 或 4
                states, actions, rewards, next_states, dones = memory.sample(batch_size)
                # states = states.to(device)
                # next_states = next_states.to(device)
                # actions = actions.to(device)
                # rewards = rewards.to(device)
                # dones = dones.to(device)
                states = states.to(device, non_blocking=True)
                next_states = next_states.to(device, non_blocking=True)
                actions = actions.to(device, non_blocking=True)
                rewards = rewards.to(device, non_blocking=True)
                dones = dones.to(device, non_blocking=True)

                with torch.amp.autocast("cuda"):
                    # 計算 Q 值 / Compute Q values
                    q_values = policy_net(states)
                    q_values = q_values.gather(1, actions)  # 取得當前動作的 Q 值

                    # 計算目標 Q 值 / Compute target Q values
                    next_q_values = target_net(next_states).max(1,keepdim = True)[0].detach()
                    expected_q = rewards + (gamma * next_q_values * (1 - dones))

                    loss = F.mse_loss(q_values, expected_q)

                optimizer.zero_grad()
                
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()


        # --- 更新 target_net ---
        if frame_idx % target_update_freq == 0: 
            target_net.load_state_dict(policy_net.state_dict())
        
    epsilon = max(epsilon_end, epsilon * epsilon_decay)

    # 更新 epsilon 並紀錄統計資料 / Decay epsilon and log results
    
    reward_history.append(episode_reward)
    score_history.append(info['score'])
    
    print(f"Episode {episode + 1:3d}, Reward: {episode_reward:7.2f}, Score: {info['score']:7.2f}, Epsilon: {epsilon:5.3f}")

    # 儲存模型（若比目前最佳分數更好，或每 50 回合）
    if (episode + 1) % 50 == 0 or info['score'] > best_score:
        best_score = max(best_score, info['score'])

        torch.save({
            'policy_net': policy_net.state_dict(),
            'target_net': target_net.state_dict(),
            'optimizer': optimizer.state_dict(),
            'epsilon': epsilon,
            'episode': episode,
            'total_steps': frame_idx,
            'best_score': best_score,
            'reward_history': reward_history,
            'score_history': score_history,
        }, 'checkpoint.pth')

        print(f"Checkpoint saved at episode {episode + 1}, best score: {best_score:.2f}")

env.close()
# Out:
# C:\Users\Wei\AppData\Local\Temp\ipykernel_35352\3044585819.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('checkpoint.pth', map_location=device)
# Loaded checkpoint from episode 800, best score: 1730.00, epsilon=0.670
# Episode 801, Reward: -106.27, Score:  202.00, Epsilon: 0.670
# Episode 802, Reward:  -96.57, Score:  236.00, Epsilon: 0.670
# Episode 803, Reward: -127.20, Score:  134.00, Epsilon: 0.669
# Episode 804, Reward:  -27.59, Score:  426.00, Epsilon: 0.669
# Episode 805, Reward: -159.28, Score:  240.00, Epsilon: 0.669
# Episode 806, Reward:  -95.11, Score:  448.00, Epsilon: 0.668
# Episode 807, Reward:  -92.50, Score:  366.00, Epsilon: 0.668
# Episode 808, Reward: -141.48, Score:  204.00, Epsilon: 0.668
# Episode 809, Reward: -139.97, Score:  146.00, Epsilon: 0.667
# Episode 810, Reward:  -98.90, Score:  218.00, Epsilon: 0.667
# Episode 811, Reward:  -81.96, Score:  350.00, Epsilon: 0.667
# Episode 812, Reward: -149.69, Score:  470.00, Epsilon: 0.666
# Episode 813, Reward: -116.99, Score:  444.00, Epsilon: 0.666
# Episode 814, Reward: -144.48, Score:  158.00, Epsilon: 0.666
# Episode 815, Reward: -109.58, Score:  220.00, Epsilon: 0.665
# Episode 816, Reward:  -31.55, Score:  768.00, Epsilon: 0.665
# Episode 817, Reward: -165.84, Score:  234.00, Epsilon: 0.665
# Episode 818, Reward: -116.35, Score:  370.00, Epsilon: 0.664
# Episode 819, Reward:  -97.31, Score:  268.00, Epsilon: 0.664
# Episode 820, Reward:  -67.03, Score:  424.00, Epsilon: 0.664
# Episode 821, Reward: -135.20, Score:  270.00, Epsilon: 0.663
# Episode 822, Reward:  -62.57, Score:  430.00, Epsilon: 0.663
# Episode 823, Reward: -140.41, Score:  266.00, Epsilon: 0.663
# Episode 824, Reward:  -80.79, Score:  466.00, Epsilon: 0.662
# Episode 825, Reward: -140.85, Score:  332.00, Epsilon: 0.662
# Episode 826, Reward:  -52.60, Score:  530.00, Epsilon: 0.662
# Episode 827, Reward: -119.54, Score:  364.00, Epsilon: 0.661
# Episode 828, Reward: -132.82, Score:  390.00, Epsilon: 0.661
# Episode 829, Reward: -127.78, Score:  548.00, Epsilon: 0.661
# Episode 830, Reward: -136.49, Score:  316.00, Epsilon: 0.660
# Episode 831, Reward: -150.20, Score:  126.00, Epsilon: 0.660
# Episode 832, Reward:  -82.85, Score:  212.00, Epsilon: 0.660
# Episode 833, Reward: -113.04, Score:  222.00, Epsilon: 0.659
# Episode 834, Reward:  -87.83, Score:  354.00, Epsilon: 0.659
# Episode 835, Reward:  -88.09, Score:  354.00, Epsilon: 0.659
# Episode 836, Reward: -102.32, Score:  532.00, Epsilon: 0.658
# Episode 837, Reward: -108.53, Score:  448.00, Epsilon: 0.658
# Episode 838, Reward: -183.43, Score:  248.00, Epsilon: 0.658
# Episode 839, Reward:  -94.09, Score:  462.00, Epsilon: 0.657
# Episode 840, Reward:  -73.05, Score:  406.00, Epsilon: 0.657
# Episode 841, Reward: -147.15, Score:  188.00, Epsilon: 0.657
# Episode 842, Reward:  -87.04, Score:  366.00, Epsilon: 0.656
# Episode 843, Reward:  -72.61, Score:  740.00, Epsilon: 0.656
# Episode 844, Reward: -131.02, Score:  418.00, Epsilon: 0.656
# Episode 845, Reward: -115.41, Score:  264.00, Epsilon: 0.655
# Episode 846, Reward:  -14.37, Score:  628.00, Epsilon: 0.655
# Episode 847, Reward: -143.60, Score:  388.00, Epsilon: 0.655
# Episode 848, Reward: -110.52, Score:  274.00, Epsilon: 0.654
# Episode 849, Reward:  -75.45, Score:  510.00, Epsilon: 0.654
# Episode 850, Reward: -145.63, Score:  238.00, Epsilon: 0.654
# Checkpoint saved at episode 850, best score: 1730.00
# Episode 851, Reward:  -49.18, Score:  402.00, Epsilon: 0.653
# Episode 852, Reward: -123.02, Score:  202.00, Epsilon: 0.653
# Episode 853, Reward: -133.20, Score:  354.00, Epsilon: 0.653
# Episode 854, Reward:  -98.96, Score:  448.00, Epsilon: 0.652
# Episode 855, Reward: -131.00, Score:  386.00, Epsilon: 0.652
# Episode 856, Reward: -128.01, Score:  124.00, Epsilon: 0.652
# Episode 857, Reward:  -53.38, Score:  386.00, Epsilon: 0.651
# Episode 858, Reward: -110.68, Score:  484.00, Epsilon: 0.651
# Episode 859, Reward: -116.20, Score:  918.00, Epsilon: 0.651
# Episode 860, Reward: -208.23, Score:  210.00, Epsilon: 0.650
# Episode 861, Reward:  -97.73, Score:  148.00, Epsilon: 0.650
# Episode 862, Reward:  -84.65, Score:  320.00, Epsilon: 0.650
# Episode 863, Reward:  -49.67, Score:  728.00, Epsilon: 0.649
# Episode 864, Reward: -189.87, Score:  216.00, Epsilon: 0.649
# Episode 865, Reward:  -99.10, Score:  236.00, Epsilon: 0.649
# Episode 866, Reward: -194.93, Score:  204.00, Epsilon: 0.648
# Episode 867, Reward: -129.05, Score:  402.00, Epsilon: 0.648
# Episode 868, Reward: -170.75, Score:  112.00, Epsilon: 0.648
# Episode 869, Reward:  -55.63, Score:  294.00, Epsilon: 0.648
# Episode 870, Reward:  -73.13, Score:  308.00, Epsilon: 0.647
# Episode 871, Reward:  -84.07, Score:  560.00, Epsilon: 0.647
# Episode 872, Reward: -125.77, Score:  282.00, Epsilon: 0.647
# Episode 873, Reward: -137.40, Score:  294.00, Epsilon: 0.646
# Episode 874, Reward: -135.12, Score:  152.00, Epsilon: 0.646
# Episode 875, Reward:  -42.34, Score:  424.00, Epsilon: 0.646
# Episode 876, Reward:  -98.94, Score:  448.00, Epsilon: 0.645
# Episode 877, Reward:  -94.69, Score:  406.00, Epsilon: 0.645
# Episode 878, Reward:  -84.50, Score:  448.00, Epsilon: 0.645
# Episode 879, Reward: -104.07, Score:  362.00, Epsilon: 0.644
# Episode 880, Reward: -137.73, Score:  416.00, Epsilon: 0.644
# Episode 881, Reward: -131.37, Score:  328.00, Epsilon: 0.644
# Episode 882, Reward: -138.57, Score:  496.00, Epsilon: 0.643
# Episode 883, Reward: -135.52, Score:  222.00, Epsilon: 0.643
# Episode 884, Reward: -126.38, Score:  376.00, Epsilon: 0.643
# Episode 885, Reward:  -96.57, Score:  434.00, Epsilon: 0.642
# Episode 886, Reward: -135.63, Score:  508.00, Epsilon: 0.642
# Episode 887, Reward: -163.90, Score:  358.00, Epsilon: 0.642
# Episode 888, Reward:  -70.57, Score:  470.00, Epsilon: 0.641
# Episode 889, Reward: -123.69, Score:  366.00, Epsilon: 0.641
# Episode 890, Reward:  -86.97, Score:  548.00, Epsilon: 0.641
# Episode 891, Reward: -131.32, Score:  268.00, Epsilon: 0.640
# Episode 892, Reward: -110.30, Score:  308.00, Epsilon: 0.640
# Episode 893, Reward: -104.87, Score:  364.00, Epsilon: 0.640
# Episode 894, Reward:  -84.99, Score:  390.00, Epsilon: 0.639
# Episode 895, Reward:  -15.60, Score:  614.00, Epsilon: 0.639
# Episode 896, Reward: -145.46, Score:  296.00, Epsilon: 0.639
# Episode 897, Reward: -107.71, Score:  420.00, Epsilon: 0.639
# Episode 898, Reward: -141.76, Score:  254.00, Epsilon: 0.638
# Episode 899, Reward:  -81.93, Score:  260.00, Epsilon: 0.638
# Episode 900, Reward: -123.98, Score:  280.00, Epsilon: 0.638
# Checkpoint saved at episode 900, best score: 1730.00
# Episode 901, Reward: -107.38, Score:  378.00, Epsilon: 0.637
# Episode 902, Reward:  -97.27, Score:  372.00, Epsilon: 0.637
# Episode 903, Reward:  -82.34, Score:  468.00, Epsilon: 0.637
# Episode 904, Reward:  -90.14, Score:  800.00, Epsilon: 0.636
# Episode 905, Reward: -113.76, Score:  498.00, Epsilon: 0.636
# Episode 906, Reward:  -84.00, Score:  514.00, Epsilon: 0.636
# Episode 907, Reward:  -73.93, Score:  624.00, Epsilon: 0.635
# Episode 908, Reward:  -54.92, Score:  776.00, Epsilon: 0.635
# Episode 909, Reward: -115.52, Score:  264.00, Epsilon: 0.635
# Episode 910, Reward:  -18.64, Score:  688.00, Epsilon: 0.634
# Episode 911, Reward: -170.83, Score:  398.00, Epsilon: 0.634
# Episode 912, Reward:  -87.84, Score:  496.00, Epsilon: 0.634
# Episode 913, Reward: -135.66, Score:  160.00, Epsilon: 0.633
# Episode 914, Reward: -105.16, Score:  284.00, Epsilon: 0.633
# Episode 915, Reward: -115.79, Score:  180.00, Epsilon: 0.633
# Episode 916, Reward:  -92.11, Score:  404.00, Epsilon: 0.632
# Episode 917, Reward: -111.98, Score:  474.00, Epsilon: 0.632
# Episode 918, Reward: -134.03, Score:  426.00, Epsilon: 0.632
# Episode 919, Reward: -138.61, Score:  276.00, Epsilon: 0.632
# Episode 920, Reward: -133.88, Score:  420.00, Epsilon: 0.631
# Episode 921, Reward: -141.37, Score:  248.00, Epsilon: 0.631
# Episode 922, Reward:  -98.65, Score:  510.00, Epsilon: 0.631
# Episode 923, Reward: -175.47, Score:  360.00, Epsilon: 0.630
# Episode 924, Reward: -112.76, Score:  380.00, Epsilon: 0.630
# Episode 925, Reward: -108.98, Score:  350.00, Epsilon: 0.630
# Episode 926, Reward:  -73.49, Score:  306.00, Epsilon: 0.629
# Episode 927, Reward: -103.41, Score:  396.00, Epsilon: 0.629
# Episode 928, Reward: -104.80, Score:  454.00, Epsilon: 0.629
# Episode 929, Reward: -190.68, Score:  310.00, Epsilon: 0.628
# Episode 930, Reward: -155.09, Score:  302.00, Epsilon: 0.628
# Episode 931, Reward:  -91.44, Score:  304.00, Epsilon: 0.628
# Episode 932, Reward:  -96.92, Score:  412.00, Epsilon: 0.627
# Episode 933, Reward:  -97.83, Score:  286.00, Epsilon: 0.627
# Episode 934, Reward:  -86.59, Score:  408.00, Epsilon: 0.627
# Episode 935, Reward: -109.35, Score:  288.00, Epsilon: 0.626
# Episode 936, Reward: -111.79, Score:  432.00, Epsilon: 0.626
# Episode 937, Reward: -110.87, Score:  194.00, Epsilon: 0.626
# Episode 938, Reward: -146.89, Score:  134.00, Epsilon: 0.626
# Episode 939, Reward:    1.73, Score:  712.00, Epsilon: 0.625
# Episode 940, Reward: -175.69, Score:  158.00, Epsilon: 0.625
# Episode 941, Reward:  -47.43, Score:  524.00, Epsilon: 0.625
# Episode 942, Reward: -119.24, Score:  478.00, Epsilon: 0.624
# Episode 943, Reward: -102.92, Score:  534.00, Epsilon: 0.624
# Episode 944, Reward: -133.17, Score:  338.00, Epsilon: 0.624
# Episode 945, Reward:  -87.87, Score:  470.00, Epsilon: 0.623
# Episode 946, Reward: -110.23, Score:  352.00, Epsilon: 0.623
# Episode 947, Reward: -137.63, Score:  310.00, Epsilon: 0.623
# Episode 948, Reward: -128.34, Score:  228.00, Epsilon: 0.622
# Episode 949, Reward:  -58.72, Score:  428.00, Epsilon: 0.622
# Episode 950, Reward:  -98.66, Score:  570.00, Epsilon: 0.622
# Checkpoint saved at episode 950, best score: 1730.00
# Episode 951, Reward: -168.41, Score:  282.00, Epsilon: 0.622
# Episode 952, Reward:  -66.76, Score:  302.00, Epsilon: 0.621
# Episode 953, Reward:  -55.26, Score:  686.00, Epsilon: 0.621
# Episode 954, Reward: -134.73, Score:  398.00, Epsilon: 0.621
# Episode 955, Reward: -160.59, Score:  306.00, Epsilon: 0.620
# Episode 956, Reward:  -43.70, Score:  590.00, Epsilon: 0.620
# Episode 957, Reward: -119.48, Score:  490.00, Epsilon: 0.620
# Episode 958, Reward: -136.92, Score:  236.00, Epsilon: 0.619
# Episode 959, Reward:  -68.70, Score:  532.00, Epsilon: 0.619
# Episode 960, Reward: -174.58, Score:  342.00, Epsilon: 0.619
# Episode 961, Reward: -137.19, Score:  206.00, Epsilon: 0.618
# Episode 962, Reward:  -83.70, Score:  368.00, Epsilon: 0.618
# Episode 963, Reward: -117.99, Score:  556.00, Epsilon: 0.618
# Episode 964, Reward: -146.12, Score:  794.00, Epsilon: 0.617
# Episode 965, Reward: -150.69, Score:  438.00, Epsilon: 0.617
# Episode 966, Reward:  -67.87, Score:  616.00, Epsilon: 0.617
# Episode 967, Reward:  -98.02, Score:  600.00, Epsilon: 0.617
# Episode 968, Reward:  -94.14, Score:  650.00, Epsilon: 0.616
# Episode 969, Reward: -191.64, Score:  186.00, Epsilon: 0.616
# Episode 970, Reward:  -94.05, Score:  296.00, Epsilon: 0.616
# Episode 971, Reward: -103.01, Score:  428.00, Epsilon: 0.615
# Episode 972, Reward: -194.90, Score:  546.00, Epsilon: 0.615
# Episode 973, Reward: -111.20, Score:  346.00, Epsilon: 0.615
# Episode 974, Reward:  -80.19, Score:  514.00, Epsilon: 0.614
# Episode 975, Reward:  -99.96, Score:  572.00, Epsilon: 0.614
# Episode 976, Reward: -166.86, Score:  456.00, Epsilon: 0.614
# Episode 977, Reward:  -73.13, Score:  480.00, Epsilon: 0.613
# Episode 978, Reward:  -88.26, Score:  506.00, Epsilon: 0.613
# Episode 979, Reward: -106.30, Score:  326.00, Epsilon: 0.613
# Episode 980, Reward:  -45.45, Score:  596.00, Epsilon: 0.613
# Episode 981, Reward: -151.61, Score:  306.00, Epsilon: 0.612
# Episode 982, Reward: -125.17, Score:  162.00, Epsilon: 0.612
# Episode 983, Reward:  -76.28, Score:  422.00, Epsilon: 0.612
# Episode 984, Reward:  -72.63, Score:  590.00, Epsilon: 0.611
# Episode 985, Reward: -126.30, Score:  308.00, Epsilon: 0.611
# Episode 986, Reward:  -90.85, Score:  556.00, Epsilon: 0.611
# Episode 987, Reward: -127.24, Score:  400.00, Epsilon: 0.610
# Episode 988, Reward: -116.07, Score:  328.00, Epsilon: 0.610
# Episode 989, Reward: -131.06, Score:  480.00, Epsilon: 0.610
# Episode 990, Reward: -102.77, Score:  728.00, Epsilon: 0.609
# Episode 991, Reward: -106.87, Score:  710.00, Epsilon: 0.609
# Episode 992, Reward: -149.43, Score:  222.00, Epsilon: 0.609
# Episode 993, Reward: -111.16, Score:  310.00, Epsilon: 0.609
# Episode 994, Reward: -153.34, Score:  212.00, Epsilon: 0.608
# Episode 995, Reward:  -77.79, Score:  388.00, Epsilon: 0.608
# Episode 996, Reward: -113.43, Score:  382.00, Epsilon: 0.608
# Episode 997, Reward: -117.69, Score:  356.00, Epsilon: 0.607
# Episode 998, Reward: -137.21, Score:  146.00, Epsilon: 0.607
# Episode 999, Reward:   -2.77, Score:  670.00, Epsilon: 0.607
# Episode 1000, Reward: -173.45, Score:  310.00, Epsilon: 0.606
# Checkpoint saved at episode 1000, best score: 1730.00
# Episode 1001, Reward: -144.26, Score:  346.00, Epsilon: 0.606
# Episode 1002, Reward: -136.97, Score:  186.00, Epsilon: 0.606
# Episode 1003, Reward: -110.99, Score:  228.00, Epsilon: 0.606
# Episode 1004, Reward: -103.11, Score:  328.00, Epsilon: 0.605
# Episode 1005, Reward: -126.51, Score:  234.00, Epsilon: 0.605
# Episode 1006, Reward:  -60.06, Score:  378.00, Epsilon: 0.605
# Episode 1007, Reward: -130.34, Score:  366.00, Epsilon: 0.604
# Episode 1008, Reward:  -71.75, Score:  396.00, Epsilon: 0.604
# Episode 1009, Reward: -199.71, Score:  104.00, Epsilon: 0.604
# Episode 1010, Reward:  -75.09, Score:  366.00, Epsilon: 0.603
# Episode 1011, Reward: -101.22, Score:  302.00, Epsilon: 0.603
# Episode 1012, Reward: -139.05, Score:  300.00, Epsilon: 0.603
# Episode 1013, Reward: -155.63, Score:  406.00, Epsilon: 0.603
# Episode 1014, Reward:  -89.24, Score:  186.00, Epsilon: 0.602
# Episode 1015, Reward: -124.41, Score:  266.00, Epsilon: 0.602
# Episode 1016, Reward: -156.21, Score:  238.00, Epsilon: 0.602
# Episode 1017, Reward: -138.18, Score:  172.00, Epsilon: 0.601
# Episode 1018, Reward:  -94.81, Score:  340.00, Epsilon: 0.601
# Episode 1019, Reward:  -98.21, Score:  532.00, Epsilon: 0.601
# Episode 1020, Reward: -119.79, Score:  218.00, Epsilon: 0.600
# Episode 1021, Reward:  -87.40, Score:  332.00, Epsilon: 0.600
# Episode 1022, Reward:  -30.68, Score:  796.00, Epsilon: 0.600
# Episode 1023, Reward: -128.71, Score:  468.00, Epsilon: 0.600
# Episode 1024, Reward: -134.30, Score:  144.00, Epsilon: 0.599
# Episode 1025, Reward: -103.31, Score:  132.00, Epsilon: 0.599
# Episode 1026, Reward:  -61.00, Score:  470.00, Epsilon: 0.599
# Episode 1027, Reward: -122.88, Score:  378.00, Epsilon: 0.598
# Episode 1028, Reward: -104.47, Score:  438.00, Epsilon: 0.598
# Episode 1029, Reward:  -70.26, Score:  660.00, Epsilon: 0.598
# Episode 1030, Reward: -195.44, Score:  324.00, Epsilon: 0.597
# Episode 1031, Reward: -137.04, Score:  332.00, Epsilon: 0.597
# Episode 1032, Reward:  -47.33, Score:  660.00, Epsilon: 0.597
# Episode 1033, Reward: -130.36, Score:  274.00, Epsilon: 0.597
# Episode 1034, Reward:  -79.97, Score:  494.00, Epsilon: 0.596
# Episode 1035, Reward: -145.42, Score:  388.00, Epsilon: 0.596
# Episode 1036, Reward: -108.10, Score:  342.00, Epsilon: 0.596
# Episode 1037, Reward: -140.27, Score:  182.00, Epsilon: 0.595
# Episode 1038, Reward:  -20.15, Score:  552.00, Epsilon: 0.595
# Episode 1039, Reward: -130.46, Score:  380.00, Epsilon: 0.595
# Episode 1040, Reward: -123.53, Score:  212.00, Epsilon: 0.594
# Episode 1041, Reward: -107.50, Score:  232.00, Epsilon: 0.594
# Episode 1042, Reward:  -56.33, Score:  552.00, Epsilon: 0.594
# Episode 1043, Reward: -172.94, Score:  182.00, Epsilon: 0.594
# Episode 1044, Reward: -164.61, Score:  188.00, Epsilon: 0.593
# Episode 1045, Reward:  -63.67, Score:  324.00, Epsilon: 0.593
# Episode 1046, Reward: -165.72, Score:  160.00, Epsilon: 0.593
# Episode 1047, Reward: -116.75, Score:  204.00, Epsilon: 0.592
# Episode 1048, Reward:  -89.01, Score:  372.00, Epsilon: 0.592
# Episode 1049, Reward: -104.03, Score:  430.00, Epsilon: 0.592
# Episode 1050, Reward: -156.01, Score:  342.00, Epsilon: 0.591
# Checkpoint saved at episode 1050, best score: 1730.00
# Episode 1051, Reward: -101.79, Score:  268.00, Epsilon: 0.591
# Episode 1052, Reward:  -74.73, Score:  448.00, Epsilon: 0.591
# Episode 1053, Reward:  -84.69, Score:  470.00, Epsilon: 0.591
# Episode 1054, Reward: -158.75, Score:  264.00, Epsilon: 0.590
# Episode 1055, Reward:  -91.96, Score:  202.00, Epsilon: 0.590
# Episode 1056, Reward:  -51.87, Score:  748.00, Epsilon: 0.590
# Episode 1057, Reward: -161.22, Score:  456.00, Epsilon: 0.589
# Episode 1058, Reward: -117.48, Score:  464.00, Epsilon: 0.589
# Episode 1059, Reward: -160.64, Score:  296.00, Epsilon: 0.589
# Episode 1060, Reward: -114.30, Score:  390.00, Epsilon: 0.589
# Episode 1061, Reward: -116.37, Score:  534.00, Epsilon: 0.588
# Episode 1062, Reward: -139.80, Score:  440.00, Epsilon: 0.588
# Episode 1063, Reward: -115.01, Score:  448.00, Epsilon: 0.588
# Episode 1064, Reward: -160.64, Score:  374.00, Epsilon: 0.587
# Episode 1065, Reward: -113.39, Score:  152.00, Epsilon: 0.587
# Episode 1066, Reward: -118.65, Score:  176.00, Epsilon: 0.587
# Episode 1067, Reward:  -75.41, Score:  242.00, Epsilon: 0.586
# Episode 1068, Reward: -146.36, Score:  440.00, Epsilon: 0.586
# Episode 1069, Reward: -133.16, Score:  136.00, Epsilon: 0.586
# Episode 1070, Reward:  -90.16, Score:  414.00, Epsilon: 0.586
# Episode 1071, Reward: -118.91, Score:  328.00, Epsilon: 0.585
# Episode 1072, Reward: -121.81, Score:  300.00, Epsilon: 0.585
# Episode 1073, Reward: -104.35, Score:  304.00, Epsilon: 0.585
# Episode 1074, Reward: -119.59, Score:  234.00, Epsilon: 0.584
# Episode 1075, Reward:  -87.05, Score:  176.00, Epsilon: 0.584
# Episode 1076, Reward:  -89.41, Score:  322.00, Epsilon: 0.584
# Episode 1077, Reward:  -98.87, Score:  204.00, Epsilon: 0.584
# Episode 1078, Reward: -113.59, Score:  228.00, Epsilon: 0.583
# Episode 1079, Reward:  -89.76, Score:  432.00, Epsilon: 0.583
# Episode 1080, Reward:  -90.10, Score:  262.00, Epsilon: 0.583
# Episode 1081, Reward: -101.35, Score:  454.00, Epsilon: 0.582
# Episode 1082, Reward: -175.24, Score:  212.00, Epsilon: 0.582
# Episode 1083, Reward: -158.39, Score:  338.00, Epsilon: 0.582
# Episode 1084, Reward: -136.93, Score:  298.00, Epsilon: 0.582
# Episode 1085, Reward: -107.47, Score:  338.00, Epsilon: 0.581
# Episode 1086, Reward:  -85.66, Score:  484.00, Epsilon: 0.581
# Episode 1087, Reward:  -96.71, Score:  556.00, Epsilon: 0.581
# Episode 1088, Reward: -129.68, Score:  156.00, Epsilon: 0.580
# Episode 1089, Reward:  -75.07, Score:  196.00, Epsilon: 0.580
# Episode 1090, Reward: -122.63, Score:  178.00, Epsilon: 0.580
# Episode 1091, Reward: -103.35, Score:  236.00, Epsilon: 0.579
# Episode 1092, Reward:  -70.13, Score:  448.00, Epsilon: 0.579
# Episode 1093, Reward:  -86.24, Score:  460.00, Epsilon: 0.579
# Episode 1094, Reward:  -81.38, Score:  546.00, Epsilon: 0.579
# Episode 1095, Reward: -162.91, Score:  342.00, Epsilon: 0.578
# Episode 1096, Reward:  -76.16, Score:  370.00, Epsilon: 0.578
# Episode 1097, Reward:  -99.87, Score:  286.00, Epsilon: 0.578
# Episode 1098, Reward: -103.73, Score:  404.00, Epsilon: 0.577
# Episode 1099, Reward: -142.99, Score:  260.00, Epsilon: 0.577
# Episode 1100, Reward:  -38.94, Score:  604.00, Epsilon: 0.577
# Checkpoint saved at episode 1100, best score: 1730.00
# Episode 1101, Reward: -160.98, Score:  388.00, Epsilon: 0.577
# Episode 1102, Reward: -150.87, Score:  176.00, Epsilon: 0.576
# Episode 1103, Reward:  -83.99, Score:  634.00, Epsilon: 0.576
# Episode 1104, Reward: -105.06, Score:  422.00, Epsilon: 0.576
# Episode 1105, Reward: -140.86, Score:  254.00, Epsilon: 0.575
# Episode 1106, Reward:  -49.40, Score:  494.00, Epsilon: 0.575
# Episode 1107, Reward: -140.12, Score:  188.00, Epsilon: 0.575
# Episode 1108, Reward:  -97.98, Score:  376.00, Epsilon: 0.575
# Episode 1109, Reward: -141.74, Score:  120.00, Epsilon: 0.574
# Episode 1110, Reward:  -85.96, Score:  308.00, Epsilon: 0.574
# Episode 1111, Reward: -104.45, Score:  204.00, Epsilon: 0.574
# Episode 1112, Reward:  -96.11, Score:  558.00, Epsilon: 0.573
# Episode 1113, Reward:  -38.71, Score:  844.00, Epsilon: 0.573
# Episode 1114, Reward: -116.29, Score:  488.00, Epsilon: 0.573
# Episode 1115, Reward: -113.69, Score:  514.00, Epsilon: 0.573
# Episode 1116, Reward: -117.87, Score:  264.00, Epsilon: 0.572
# Episode 1117, Reward:  -94.39, Score:  270.00, Epsilon: 0.572
# Episode 1118, Reward: -140.16, Score:  122.00, Epsilon: 0.572
# Episode 1119, Reward: -126.19, Score:  364.00, Epsilon: 0.571
# Episode 1120, Reward: -191.67, Score:  220.00, Epsilon: 0.571
# Episode 1121, Reward:  -96.25, Score:  226.00, Epsilon: 0.571
# Episode 1122, Reward: -147.65, Score:  438.00, Epsilon: 0.571
# Episode 1123, Reward: -140.57, Score:  224.00, Epsilon: 0.570
# Episode 1124, Reward:  -73.53, Score:  426.00, Epsilon: 0.570
# Episode 1125, Reward: -126.58, Score:  228.00, Epsilon: 0.570
# Episode 1126, Reward:  -86.90, Score:  408.00, Epsilon: 0.569
# Episode 1127, Reward: -164.64, Score:  412.00, Epsilon: 0.569
# Episode 1128, Reward: -104.70, Score:  352.00, Epsilon: 0.569
# Episode 1129, Reward:  -82.24, Score:  350.00, Epsilon: 0.569
# Episode 1130, Reward: -114.70, Score:  202.00, Epsilon: 0.568
# Episode 1131, Reward: -164.58, Score:  360.00, Epsilon: 0.568
# Episode 1132, Reward:  -49.11, Score:  548.00, Epsilon: 0.568
# Episode 1133, Reward:  -82.95, Score:  550.00, Epsilon: 0.567
# Episode 1134, Reward:  -41.93, Score:  810.00, Epsilon: 0.567
# Episode 1135, Reward: -164.15, Score:  490.00, Epsilon: 0.567
# Episode 1136, Reward: -142.50, Score:  382.00, Epsilon: 0.567
# Episode 1137, Reward: -106.81, Score:  470.00, Epsilon: 0.566
# Episode 1138, Reward: -160.21, Score:  212.00, Epsilon: 0.566
# Episode 1139, Reward: -114.44, Score:  430.00, Epsilon: 0.566
# Episode 1140, Reward: -133.73, Score:  244.00, Epsilon: 0.565
# Episode 1141, Reward:   73.03, Score: 1184.00, Epsilon: 0.565
# Episode 1142, Reward: -162.46, Score:  420.00, Epsilon: 0.565
# Episode 1143, Reward: -163.78, Score:  178.00, Epsilon: 0.565
# Episode 1144, Reward: -101.44, Score:  300.00, Epsilon: 0.564
# Episode 1145, Reward:  -96.98, Score:  368.00, Epsilon: 0.564
# Episode 1146, Reward:  -70.17, Score:  470.00, Epsilon: 0.564
# Episode 1147, Reward: -141.04, Score:  214.00, Epsilon: 0.563
# Episode 1148, Reward: -118.44, Score:  402.00, Epsilon: 0.563
# Episode 1149, Reward: -121.98, Score:  410.00, Epsilon: 0.563
# Episode 1150, Reward: -131.02, Score:  130.00, Epsilon: 0.563
# Checkpoint saved at episode 1150, best score: 1730.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 104
#     101         optimizer.zero_grad()
#     103         scaler.scale(loss).backward()
# --> 104         scaler.step(optimizer)
#     105         scaler.update()
#     108 # --- 更新 target_net ---
#
# File z:\RL\.venv\lib\site-packages\torch\amp\grad_scaler.py:454, in GradScaler.step(self, optimizer, *args, **kwargs)
#     448     self.unscale_(optimizer)
#     450 assert (
#     451     len(optimizer_state["found_inf_per_device"]) > 0
#     452 ), "No inf checks were recorded for this optimizer."
# --> 454 retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     456 optimizer_state["stage"] = OptState.STEPPED
#     458 return retval
#
# File z:\RL\.venv\lib\site-packages\torch\amp\grad_scaler.py:351, in GradScaler._maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     343 def _maybe_opt_step(
#     344     self,
#     345     optimizer: torch.optim.Optimizer,
#    (...)
#     348     **kwargs: Any,
#     349 ) -> Optional[float]:
#     350     retval: Optional[float] = None
# --> 351     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     352         retval = optimizer.step(*args, **kwargs)
#     353     return retval
#
# File z:\RL\.venv\lib\site-packages\torch\amp\grad_scaler.py:351, in <genexpr>(.0)
#     343 def _maybe_opt_step(
#     344     self,
#     345     optimizer: torch.optim.Optimizer,
#    (...)
#     348     **kwargs: Any,
#     349 ) -> Optional[float]:
#     350     retval: Optional[float] = None
# --> 351     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     352         retval = optimizer.step(*args, **kwargs)
#     353     return retval
#
# KeyboardInterrupt:

# %%
from scipy.ndimage import gaussian_filter1d

reward_smooth = gaussian_filter1d(reward_history, sigma=50)
score_smooth = gaussian_filter1d(score_history, sigma=50)

# 畫圖
# plt.figure(figsize=(10, 5))
plt.plot(reward_history, label='Total Reward', alpha=0.8)
plt.plot(score_history, label='Score', alpha=0.8)
plt.plot(reward_smooth, label='Smoothed Total Reward', linewidth=2)
plt.plot(score_smooth, label='Smoothed Score', linewidth=2)

plt.legend(loc='upper left')
plt.xlabel("Episode")
plt.ylabel("Value")
plt.title("Training Reward Over Episodes")
plt.grid(True)
plt.tight_layout()
# plt.savefig("dqn_training_curve.png")
